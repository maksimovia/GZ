# %%
from multiprocessing import Pool

import ASWmultiprocess as PC

if __name__ == "__main__":
    
    # "Кнопки"
#     t_air_list = [-29,-15, 0, 8, 15] # - температуры, при которых необходимо расчитать
    t_air_list = [-5] # - температуры, при которых необходимо расчитать
#     t_air_list = [-29] # - температуры, при которых необходимо расчитать
    s = len(t_air_list)# - длина списка температур
    nagr_list = 1# -нагрузки, при которых необходимо расчитать
    multic = False
    # Флаги
    ASWbul = [1] #- 0- нет аккум 1- загрузка аккумулятора, 2- разгрузка аккумулятора
    sn = len(ASWbul)
    ASWatm = [True]  #- True- атмосферный аккум False- аккум под давлением

    sq = len(ASWatm)
    PKM_zaryad = False
    # Сalculate_minimum = [False,True]
    Сalculate_minimum = [True]
    sz = len(Сalculate_minimum)
    Teplo = int(True)
    # Вкл выкл заряд по ПКМ
#     PKM_zaryad = False
    
    #ASW konstruct parametr
    Diametr = 5
    Visota=8
    kolichestvo=[1,2,3,4]
    sk = len(kolichestvo)
    lambda_min_vata = 0.045
    delta_min_vata = 0.1
    vremya=4
    vremyaojidaniya = 12

    # Основные эффективности оборудования
    KPD_PN = 0.8074
    KPD_KN = 0.75
    KPD_to = 0.99
    KPD_SP = 0.99

    # Параметры, отвечающие за процесс расчета
    Calcmethod = "hybr"
    Calctolerance = 10**-2
    Maxiterations_KU_TU = 8
    Maxiterations_cotel = 5
    Maxiterations_turbine = 25   
    
    steamVD_fraction_to_turbine=1
    
    chunks = (
                    Diametr,  # Diametr - диаметр аккумулятора
                    kolichestvo[0],  # kolichestvo -  количество баков аккумуляторов
                    Visota,  # Visota - высота аккумулятора
                    lambda_min_vata,  # - lambda_min_vata теплопроводность изолятора бака аккумулятора
                    delta_min_vata,  # - delta_min_vata толщина изолятора бака аккумулятора
                    ASWbul[0],  # ASWbul - 1- загрузка аккумулятора, 2- разгрузка аккумулятора
                    nagr_list,  # nagr - доля нагрузки от номинала
                    vremya,  # vremya - время зарядки/разрядки аккумулятора
                    vremyaojidaniya,  # vremyaojidaniya - время ожидания аккумулятора
                    t_air_list[0],
                    PKM_zaryad,
                    Сalculate_minimum[0],
                    KPD_PN,
                    KPD_KN,
                    KPD_to,
                    KPD_SP,
                    Calcmethod,
                    Calctolerance,
                    Maxiterations_KU_TU,
                    Maxiterations_cotel,
                    Maxiterations_turbine,
                    Сalculate_minimum[0],
                    Teplo,
                    steamVD_fraction_to_turbine,
                    PKM_zaryad,
                    ASWatm[0],
                )
    if multic:
        
    #####################
        for k in range(sk):

            print("Начался расчет kolichestvo=", kolichestvo[k])
            chunks = [
                (
                    Diametr,  # Diametr - диаметр аккумулятора
                    kolichestvo[k],  # kolichestvo -  количество баков аккумуляторов
                    Visota,  # Visota - высота аккумулятора
                    lambda_min_vata,  # - lambda_min_vata теплопроводность изолятора бака аккумулятора
                    delta_min_vata,  # - delta_min_vata толщина изолятора бака аккумулятора
                    ASWbul[i],  # ASWbul - 1- загрузка аккумулятора, 2- разгрузка аккумулятора
                    nagr_list,  # nagr - доля нагрузки от номинала
                    vremya,  # vremya - время зарядки/разрядки аккумулятора
                    vremyaojidaniya,  # vremyaojidaniya - время ожидания аккумулятора
                    t_air_list[j],
                    PKM_zaryad,
                    Сalculate_minimum[z],
                    KPD_PN,
                    KPD_KN,
                    KPD_to,
                    KPD_SP,
                    Calcmethod,
                    Calctolerance,
                    Maxiterations_KU_TU,
                    Maxiterations_cotel,
                    Maxiterations_turbine,
                    Сalculate_minimum[z],
                    Teplo,
                    steamVD_fraction_to_turbine,
                    PKM_zaryad,
                    ASWatm[q],
                )
                for i in range(sn)
                for j in range(s)
                for z in range(sz)
                for q in range(sq)
            ]

            with Pool(60) as pool:
                all_results = pool.map(PC.ParallelCompute, chunks,chunksize=1)
                import pandas as pd
                import openpyxl
                import os
                print(all_results)
                df = pd.DataFrame(all_results)
                pool.close()
                pool.join()
        #         df = df.Thfgh

                if kolichestvo[k]==1:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='140m3',index = False)
                if kolichestvo[k]==2:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='250m3',index = False)
                if kolichestvo[k]==3:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='400m3',index = False)
                if kolichestvo[k]==4:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='565m3',index = False)
        
    else:
        print("Soloraschet")
        PC.ParallelCompute(chunks)
        if kolichestvo[k]==1:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='140m3',index = False)
        if kolichestvo[k]==2:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='250m3',index = False)
        if kolichestvo[k]==3:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='400m3',index = False)
        if kolichestvo[k]==4:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='565m3',index = False)
# Out:
# Soloraschet
# 1.0 check
# Началась 1 итерация расчета ПГУ: --- 0.0 сек. ---
# n_GTU:  [0]
# Delta_n_GTU:  100
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Время 1 итерации расчета КУ+ТУ:---  7.2 сек. ---
# Давление на входе в ЦНД меньше нуля при температуре воздуха: -5.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: -5.0
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.058780480550884175, 0.058906699395539004, 0.059053737576395024, 0.05910848610510065]
# Погрешность давления в верхнем сетевом отборе в %:  -0.137
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 2 итерации расчета КУ+ТУ:---  28.2 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.65516, 0.67652, 0.66451]
# Pvd_it [8.05114, 7.93413, 7.8852]
# Max_error 3.5516963553190526
# fin КУ и ТУ:--- 28.2 сек. ---
# Началась 2 итерация расчета ПГУ: --- 28.4 сек. ---
# n_GTU:  [0, 0.9]
# Delta_n_GTU:  100.0
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 1 итерации расчета КУ+ТУ:---  6.9 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 2 итерации расчета КУ+ТУ:---  25.1 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.66451, 0.68921, 0.6788]
# Pvd_it [7.8852, 7.98646, 8.02911]
# Max_error 3.0189704854064607
# fin КУ и ТУ:--- 25.1 сек. ---
# Началась 3 итерация расчета ПГУ: --- 53.8 сек. ---
# n_GTU:  [0, 0.9, 0.94433]
# Delta_n_GTU:  4.694333548653541
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 1 итерации расчета КУ+ТУ:---  4.9 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 2 итерации расчета КУ+ТУ:---  22.3 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.6788, 0.69425, 0.68023]
# Pvd_it [8.02911, 8.03096, 8.03118]
# Max_error 4.0391340909087265
# fin КУ и ТУ:--- 22.3 сек. ---
# Началась 4 итерация расчета ПГУ: --- 76.4 сек. ---
# n_GTU:  [0, 0.9, 0.94433, 0.94012]
# Delta_n_GTU:  0.4478151725311712
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 1 итерации расчета КУ+ТУ:---  4.3 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 2 итерации расчета КУ+ТУ:---  19.4 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.68023, 0.69512, 0.68092]
# Pvd_it [8.03118, 8.03787, 8.03833]
# Max_error 4.0879051222845675
# fin КУ и ТУ:--- 19.4 сек. ---
# Началась 5 итерация расчета ПГУ: --- 96.1 сек. ---
# n_GTU:  [0, 0.9, 0.94433, 0.94012, 0.94144]
# Delta_n_GTU:  0.1402107409925326
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Время 1 итерации расчета КУ+ТУ:---  8.1 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 2 итерации расчета КУ+ТУ:---  37.1 сек. ---
# Время 3 итерации расчета КУ+ТУ:---  52.1 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 4 итерации расчета КУ+ТУ:---  99.5 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 5 итерации расчета КУ+ТУ:---  125.8 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 6 итерации расчета КУ+ТУ:---  145.7 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 7 итерации расчета КУ+ТУ:---  163.2 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 8 итерации расчета КУ+ТУ:---  174.5 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 8
# Pnd_it [0.68092, 0.69554, 0.68082, 0.67573, 0.66301, 0.65901, 0.65792, 0.6576, 0.65753]
# Pvd_it [8.03833, 8.03831, 8.04103, 8.03734, 8.07469, 8.09007, 8.09636, 8.09875, 8.09969]
# Max_error 0.023264985793327357
# fin КУ и ТУ:--- 174.5 сек. ---
# Отклонение от ограничения минимальное равно 0.001486000297983552
# Относительная мощность ГТУ равна 0.9413862529911923
# fin минимальная мощность ПГУ:--- 270.9 сек. ---
# n_GTU: [0, 0.9, 0.94433, 0.94012, 0.94144, 0.94139]
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Время 1 итерации расчета КУ+ТУ:---  11.8 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 2 итерации расчета КУ+ТУ:---  37.9 сек. ---
# Время 3 итерации расчета КУ+ТУ:---  52.2 сек. ---
