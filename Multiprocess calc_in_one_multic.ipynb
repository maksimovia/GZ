# %%
from multiprocessing import Pool

import ASWmultiprocess as PC

if __name__ == "__main__":
    
    # "Кнопки"
#     t_air_list = [-29,-15, 0, 8, 15] # - температуры, при которых необходимо расчитать
    t_air_list = [-5] # - температуры, при которых необходимо расчитать
#     t_air_list = [-29] # - температуры, при которых необходимо расчитать
    s = len(t_air_list)# - длина списка температур
    nagr_list = 1# -нагрузки, при которых необходимо расчитать
    multic = False
    # Флаги
    ASWbul = [1] #- 0- нет аккум 1- загрузка аккумулятора, 2- разгрузка аккумулятора
    sn = len(ASWbul)
    ASWatm = [True]  #- True- атмосферный аккум False- аккум под давлением

    sq = len(ASWatm)
    PKM_zaryad = False
    # Сalculate_minimum = [False,True]
    Сalculate_minimum = [True]
    sz = len(Сalculate_minimum)
    Teplo = int(True)
    # Вкл выкл заряд по ПКМ
#     PKM_zaryad = False
    
    #ASW konstruct parametr
    Diametr = 5
    Visota=8
    kolichestvo=[1,2,3,4]
    sk = len(kolichestvo)
    lambda_min_vata = 0.045
    delta_min_vata = 0.1
    vremya=4
    vremyaojidaniya = 12

    # Основные эффективности оборудования
    KPD_PN = 0.8074
    KPD_KN = 0.75
    KPD_to = 0.99
    KPD_SP = 0.99

    # Параметры, отвечающие за процесс расчета
    Calcmethod = "hybr"
    Calctolerance = 10**-2
    Maxiterations_KU_TU = 8
    Maxiterations_cotel = 4
    Maxiterations_turbine = 20   
    
    steamVD_fraction_to_turbine=1
    
    chunks = (
                    Diametr,  # Diametr - диаметр аккумулятора
                    kolichestvo[0],  # kolichestvo -  количество баков аккумуляторов
                    Visota,  # Visota - высота аккумулятора
                    lambda_min_vata,  # - lambda_min_vata теплопроводность изолятора бака аккумулятора
                    delta_min_vata,  # - delta_min_vata толщина изолятора бака аккумулятора
                    ASWbul[0],  # ASWbul - 1- загрузка аккумулятора, 2- разгрузка аккумулятора
                    nagr_list,  # nagr - доля нагрузки от номинала
                    vremya,  # vremya - время зарядки/разрядки аккумулятора
                    vremyaojidaniya,  # vremyaojidaniya - время ожидания аккумулятора
                    t_air_list[0],
                    PKM_zaryad,
                    Сalculate_minimum[0],
                    KPD_PN,
                    KPD_KN,
                    KPD_to,
                    KPD_SP,
                    Calcmethod,
                    Calctolerance,
                    Maxiterations_KU_TU,
                    Maxiterations_cotel,
                    Maxiterations_turbine,
                    Сalculate_minimum[0],
                    Teplo,
                    steamVD_fraction_to_turbine,
                    PKM_zaryad,
                    ASWatm[0],
                )
    if multic:
        
    #####################
        for k in range(sk):

            print("Начался расчет kolichestvo=", kolichestvo[k])
            chunks = [
                (
                    Diametr,  # Diametr - диаметр аккумулятора
                    kolichestvo[k],  # kolichestvo -  количество баков аккумуляторов
                    Visota,  # Visota - высота аккумулятора
                    lambda_min_vata,  # - lambda_min_vata теплопроводность изолятора бака аккумулятора
                    delta_min_vata,  # - delta_min_vata толщина изолятора бака аккумулятора
                    ASWbul[i],  # ASWbul - 1- загрузка аккумулятора, 2- разгрузка аккумулятора
                    nagr_list,  # nagr - доля нагрузки от номинала
                    vremya,  # vremya - время зарядки/разрядки аккумулятора
                    vremyaojidaniya,  # vremyaojidaniya - время ожидания аккумулятора
                    t_air_list[j],
                    PKM_zaryad,
                    Сalculate_minimum[z],
                    KPD_PN,
                    KPD_KN,
                    KPD_to,
                    KPD_SP,
                    Calcmethod,
                    Calctolerance,
                    Maxiterations_KU_TU,
                    Maxiterations_cotel,
                    Maxiterations_turbine,
                    Сalculate_minimum[z],
                    Teplo,
                    steamVD_fraction_to_turbine,
                    PKM_zaryad,
                    ASWatm[q],
                )
                for i in range(sn)
                for j in range(s)
                for z in range(sz)
                for q in range(sq)
            ]

            with Pool(60) as pool:
                all_results = pool.map(PC.ParallelCompute, chunks,chunksize=1)
                import pandas as pd
                import openpyxl
                import os
                print(all_results)
                df = pd.DataFrame(all_results)
                pool.close()
                pool.join()
        #         df = df.Thfgh

                if kolichestvo[k]==1:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='140m3',index = False)
                if kolichestvo[k]==2:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='250m3',index = False)
                if kolichestvo[k]==3:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='400m3',index = False)
                if kolichestvo[k]==4:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='565m3',index = False)
        
    else:
        print("Soloraschet")
        PC.ParallelCompute(chunks)
        if kolichestvo[k]==1:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='140m3',index = False)
        if kolichestvo[k]==2:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='250m3',index = False)
        if kolichestvo[k]==3:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='400m3',index = False)
        if kolichestvo[k]==4:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='565m3',index = False)
# Out:
# Soloraschet
# 1.0 check
# Началась 1 итерация расчета ПГУ: --- 0.0 сек. ---
# n_GTU:  [0, -1]
# Delta_n_GTU:  100
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 1 итерации расчета КУ+ТУ:---  9.1 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Давление на входе в ЦНД меньше нуля при температуре воздуха: -5.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: -5.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: -5.0
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 2 итерации расчета КУ+ТУ:---  25.5 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.65516, 0.65909, 0.61976]
# Pvd_it [8.05114, 7.06521, 6.68588]
# Max_error_P 11.935246309042888
# Max_error_G 8.77437833240116
# fin КУ и ТУ:--- 25.5 сек. ---
# Началась 2 итерация расчета ПГУ: --- 25.7 сек. ---
# n_GTU:  [0, -1, 0.9]
# Delta_n_GTU:  211.11111111111111
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 1 итерации расчета КУ+ТУ:---  7.9 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 2 итерации расчета КУ+ТУ:---  21.5 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.61976, 0.65213, 0.63696]
# Pvd_it [6.68588, 6.76148, 6.79957]
# Max_error_P 4.651624030502822
# Max_error_G 1.775908553363671
# fin КУ и ТУ:--- 21.5 сек. ---
# Началась 3 итерация расчета ПГУ: --- 47.6 сек. ---
# n_GTU:  [0, -1, 0.9, 0.99998]
# Delta_n_GTU:  9.998199963999275
# Мощность больше 1 у ГТУ
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 1 итерации расчета КУ+ТУ:---  6.2 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 2 итерации расчета КУ+ТУ:---  23.0 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.63696, 0.68644, 0.675]
# Pvd_it [6.79957, 7.03326, 7.13182]
# Max_error_P 3.33123005891292
# Max_error_G 0.09355340216049435
# fin КУ и ТУ:--- 23.0 сек. ---
# Началась 4 итерация расчета ПГУ: --- 70.9 сек. ---
# n_GTU:  [0, -1, 0.9, 0.99998, 1.09995]
# Delta_n_GTU:  9.088594936133461
# Мощность больше 1 у ГТУ
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Время 1 итерации расчета КУ+ТУ:---  7.2 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 2 итерации расчета КУ+ТУ:---  20.4 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.675, 0.70016, 0.68055]
# Pvd_it [7.13182, 7.16236, 7.1816]
# Max_error_P 5.602973927688186
# Max_error_G 0.044373155061102766
# fin КУ и ТУ:--- 20.4 сек. ---
# Началась 5 итерация расчета ПГУ: --- 91.5 сек. ---
# n_GTU:  [0, -1, 0.9, 0.99998, 1.09995, 1.1]
# Delta_n_GTU:  0.004545454545464137
# Мощность больше 1 у ГТУ
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Время 1 итерации расчета КУ+ТУ:---  35.4 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Давление на входе в ЦНД меньше нуля при температуре воздуха: -5.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: -5.0
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Время 2 итерации расчета КУ+ТУ:---  97.2 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Давление на входе в ЦНД меньше нуля при температуре воздуха: -5.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: -5.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: -5.0
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 3 итерации расчета КУ+ТУ:---  139.0 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 4 итерации расчета КУ+ТУ:---  217.4 сек. ---
# Время 5 итерации расчета КУ+ТУ:---  261.5 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Время 6 итерации расчета КУ+ТУ:---  389.9 сек. ---
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.012618005479478177, 0.0126358432566743, 0.01264345984542324, 0.012640043920326964]
# Погрешность давления в верхнем сетевом отборе в %:  0.01
# Время 7 итерации расчета КУ+ТУ:---  433.4 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.027833801792313113, 0.027829556474961915, 0.02782158065736648, 0.02781687938712903]
# Погрешность давления в верхнем сетевом отборе в %:  0.014
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Время 8 итерации расчета КУ+ТУ:---  589.6 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 8
# Pnd_it [0.68055, 0.67727, 1.04698, 0.77327, 0.97264, 1.00485, 0.82318, 1.03724, 0.84338]
# Pvd_it [7.1816, 7.04976, 7.00638, 7.12902, 7.08531, 7.14181, 8.67731, 7.67645, 8.88716]
# Max_error_P 37.38111614718217
# Max_error_G 0.005053640309868172
# fin КУ и ТУ:--- 589.6 сек. ---
# Началась 6 итерация расчета ПГУ: --- 681.4 сек. ---
# n_GTU:  [0, -1, 0.9, 0.99998, 1.09995, 1.1, 1.1]
# Delta_n_GTU:  0.0
# Мощность больше 1 у ГТУ
# 398.1007015109759 h_accum
# 0.1 self._P_accum
# 95 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Достигнуто максимальное количество итераций котла-утилизатора:3
