# %%
from multiprocessing import Pool

import ASWmultiprocess as PC

if __name__ == "__main__":
    
    # "Кнопки"
#     t_air_list = [-29,-15, 0, 8, 15] # - температуры, при которых необходимо расчитать
    t_air_list = [8] # - температуры, при которых необходимо расчитать
#     t_air_list = [-29] # - температуры, при которых необходимо расчитать
    s = len(t_air_list)# - длина списка температур
    nagr_list = 1# -нагрузки, при которых необходимо расчитать
    multic = False
    # Флаги
    ASWbul = [1] #- 0- нет аккум 1- загрузка аккумулятора, 2- разгрузка аккумулятора
    sn = len(ASWbul)
    ASWatm = [True]  #- True- атмосферный аккум False- аккум под давлением

    sq = len(ASWatm)
    PKM_zaryad = False
    # Сalculate_minimum = [False,True]
    Сalculate_minimum = [True]
    sz = len(Сalculate_minimum)
    Teplo = int(True)
    # Вкл выкл заряд по ПКМ
#     PKM_zaryad = False
    
    #ASW konstruct parametr
    Diametr = 5
    Visota=8
    kolichestvo=[1,2,3,4]
    sk = len(kolichestvo)
    lambda_min_vata = 0.045
    delta_min_vata = 0.1
    vremya=4
    vremyaojidaniya = 12

    # Основные эффективности оборудования
    KPD_PN = 0.8074
    KPD_KN = 0.75
    KPD_to = 0.99
    KPD_SP = 0.99

    # Параметры, отвечающие за процесс расчета
    Calcmethod = "hybr"
    Calctolerance = 10**-2
    Maxiterations_KU_TU = 8
    Maxiterations_cotel = 4
    Maxiterations_turbine = 20   
    
    steamVD_fraction_to_turbine=1
    
    chunks = (
                    Diametr,  # Diametr - диаметр аккумулятора
                    kolichestvo[0],  # kolichestvo -  количество баков аккумуляторов
                    Visota,  # Visota - высота аккумулятора
                    lambda_min_vata,  # - lambda_min_vata теплопроводность изолятора бака аккумулятора
                    delta_min_vata,  # - delta_min_vata толщина изолятора бака аккумулятора
                    ASWbul[0],  # ASWbul - 1- загрузка аккумулятора, 2- разгрузка аккумулятора
                    nagr_list,  # nagr - доля нагрузки от номинала
                    vremya,  # vremya - время зарядки/разрядки аккумулятора
                    vremyaojidaniya,  # vremyaojidaniya - время ожидания аккумулятора
                    t_air_list[0],
                    PKM_zaryad,
                    Сalculate_minimum[0],
                    KPD_PN,
                    KPD_KN,
                    KPD_to,
                    KPD_SP,
                    Calcmethod,
                    Calctolerance,
                    Maxiterations_KU_TU,
                    Maxiterations_cotel,
                    Maxiterations_turbine,
                    Сalculate_minimum[0],
                    Teplo,
                    steamVD_fraction_to_turbine,
                    PKM_zaryad,
                    ASWatm[0],
                )
    if multic:
        
    #####################
        for k in range(sk):

            print("Начался расчет kolichestvo=", kolichestvo[k])
            chunks = [
                (
                    Diametr,  # Diametr - диаметр аккумулятора
                    kolichestvo[k],  # kolichestvo -  количество баков аккумуляторов
                    Visota,  # Visota - высота аккумулятора
                    lambda_min_vata,  # - lambda_min_vata теплопроводность изолятора бака аккумулятора
                    delta_min_vata,  # - delta_min_vata толщина изолятора бака аккумулятора
                    ASWbul[i],  # ASWbul - 1- загрузка аккумулятора, 2- разгрузка аккумулятора
                    nagr_list,  # nagr - доля нагрузки от номинала
                    vremya,  # vremya - время зарядки/разрядки аккумулятора
                    vremyaojidaniya,  # vremyaojidaniya - время ожидания аккумулятора
                    t_air_list[j],
                    PKM_zaryad,
                    Сalculate_minimum[z],
                    KPD_PN,
                    KPD_KN,
                    KPD_to,
                    KPD_SP,
                    Calcmethod,
                    Calctolerance,
                    Maxiterations_KU_TU,
                    Maxiterations_cotel,
                    Maxiterations_turbine,
                    Сalculate_minimum[z],
                    Teplo,
                    steamVD_fraction_to_turbine,
                    PKM_zaryad,
                    ASWatm[q],
                )
                for i in range(sn)
                for j in range(s)
                for z in range(sz)
                for q in range(sq)
            ]

            with Pool(60) as pool:
                all_results = pool.map(PC.ParallelCompute, chunks,chunksize=1)
                import pandas as pd
                import openpyxl
                import os
                print(all_results)
                df = pd.DataFrame(all_results)
                pool.close()
                pool.join()
        #         df = df.Thfgh

                if kolichestvo[k]==1:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='140m3',index = False)
                if kolichestvo[k]==2:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='250m3',index = False)
                if kolichestvo[k]==3:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='400m3',index = False)
                if kolichestvo[k]==4:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='565m3',index = False)
        
    else:
        print("Soloraschet")
        PC.ParallelCompute(chunks)
        if kolichestvo[k]==1:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='140m3',index = False)
        if kolichestvo[k]==2:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='250m3',index = False)
        if kolichestvo[k]==3:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='400m3',index = False)
        if kolichestvo[k]==4:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='565m3',index = False)
# Out:
# Soloraschet
# 1.0 check
# Началась 1 итерация расчета ПГУ: --- 0.0 сек. ---
# n_GTU:  [0, -1]
# Delta_n_GTU:  100
# 377.06246187048646 h_accum
# 0.1 self._P_accum
# 90.0 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 1 итерации расчета КУ+ТУ:---  9.5 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.027760439724013576, 0.009325090391499858, 0.013920272651993533, 0.041693547026154104]
# Расход в конденсатор равен нулю
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.033138613969571386, 0.02883427218089962, 0.026210290872678395, 0.028547444723839122]
# Расход в конденсатор равен нулю
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 2 итерации расчета КУ+ТУ:---  35.0 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.63975, 0.64669, 0.60468]
# Pvd_it [7.87743, 6.98014, 6.63519]
# Max_error_P 12.99432615429762
# Max_error_G 7.18465145564681
# fin КУ и ТУ:--- 35.0 сек. ---
# Началась 2 итерация расчета ПГУ: --- 35.3 сек. ---
# n_GTU:  [0, -1, 0.9]
# Delta_n_GTU:  211.11111111111111
# 377.06246187048646 h_accum
# 0.1 self._P_accum
# 90.0 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Время 1 итерации расчета КУ+ТУ:---  8.2 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.027919584812891994, 0.026005134031730895, 0.025436400559414707, 0.027174669414857366]
# Расход в конденсатор равен нулю
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 2
# Время 2 итерации расчета КУ+ТУ:---  29.9 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.60468, 0.64273, 0.62385]
# Pvd_it [6.63519, 6.71522, 6.75795]
# Max_error_P 5.876889801991643
# Max_error_G 0.46517080330405547
# fin КУ и ТУ:--- 29.9 сек. ---
# Началась 3 итерация расчета ПГУ: --- 65.5 сек. ---
# n_GTU:  [0, -1, 0.9, 0.99998]
# Delta_n_GTU:  9.998199963999275
# Мощность больше 1 у ГТУ
# 377.06246187048646 h_accum
# 0.1 self._P_accum
# 90.0 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Время 1 итерации расчета КУ+ТУ:---  7.2 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.019406272985673163, 0.01835081853944415, 0.017980751748638293, 0.019127115016353818]
# Погрешность давления в верхнем сетевом отборе в %:  -3.439
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Время 2 итерации расчета КУ+ТУ:---  33.6 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.62385, 0.67724, 0.66172]
# Pvd_it [6.75795, 6.98932, 7.09073]
# Max_error_P 4.583119727129988
# Max_error_G 0.09998429195830223
# fin КУ и ТУ:--- 33.6 сек. ---
# Началась 4 итерация расчета ПГУ: --- 99.4 сек. ---
# n_GTU:  [0, -1, 0.9, 0.99998, 1.09995]
# Delta_n_GTU:  9.088594936133461
# Мощность больше 1 у ГТУ
# 377.06246187048646 h_accum
# 0.1 self._P_accum
# 90.0 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Время 1 итерации расчета КУ+ТУ:---  7.7 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.020636826506096096, 0.02055774502029142, 0.02008706067662169, 0.019683868498299555]
# Погрешность давления в верхнем сетевом отборе в %:  1.21
# Время 2 итерации расчета КУ+ТУ:---  30.9 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 2
# Pnd_it [0.66172, 0.68871, 0.66481]
# Pvd_it [7.09073, 7.10653, 7.12146]
# Max_error_P 6.940732082125117
# Max_error_G 0.04684612739786049
# fin КУ и ТУ:--- 30.9 сек. ---
# Началась 5 итерация расчета ПГУ: --- 130.6 сек. ---
# n_GTU:  [0, -1, 0.9, 0.99998, 1.09995, 1.09282]
# Delta_n_GTU:  0.6524404751011219
# Мощность больше 1 у ГТУ
# 377.06246187048646 h_accum
# 0.1 self._P_accum
# 90.0 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Время 1 итерации расчета КУ+ТУ:---  17.6 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.027912707253056245, 0.022256745917803356, 0.02091930198517248, 0.026364355178723275]
# Погрешность давления в верхнем сетевом отборе в %:  -16.335
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Время 2 итерации расчета КУ+ТУ:---  56.1 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 3 итерации расчета КУ+ТУ:---  91.3 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# C:\Users\NaumovVY\Documents\GitHub\GZ\cotel.py:611: RuntimeWarning: divide by zero encountered in double_scalars
#   G_rec = G_all*(h_gpk_in_60-h_gpk_in_rec) / \
# C:\Users\NaumovVY\Documents\GitHub\GZ\cotel.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   P22new = P21 - ((self.P021-self.P022)/ddp)
# C:\Users\NaumovVY\Documents\GitHub\GZ\cotel.py:595: RuntimeWarning: invalid value encountered in double_scalars
#   Qw_gpk2 = self.water_streams.at['GPK-REC', 'G']*(
# Энтальпия внутри ПЕНД стала меньше 0:  -612.9413331947926
# Энтальпия внутри ПЕНД стала меньше 0:  -186.87270289201615
# Энтальпия внутри ПЕНД стала меньше 0:  -186.8699501240385
# Энтальпия внутри ПЕНД стала меньше 0:  -18.1003717484582
# self.stream22 меньше нуля:  PPND-DROSND
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  54.639
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.008699957037164302, 0.012992252418697621, 0.016910857480544307, 0.012141970872107407]
# Погрешность давления в верхнем сетевом отборе в %:  14.307
# Время 4 итерации расчета КУ+ТУ:---  231.0 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  83.074
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  81.259
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  81.243
# Время 5 итерации расчета КУ+ТУ:---  376.5 сек. ---
# Энтальпия внутри ПЕНД стала меньше 0:  -139.30134836847992
# Энтальпия внутри ПЕНД стала меньше 0:  -268.0304789110901
# Энтальпия внутри ПЕНД стала меньше 0:  -1146.0979486683286
# Энтальпия внутри ПЕНД стала меньше 0:  -1450.741070544561
# Энтальпия внутри ПЕНД стала меньше 0:  -1569.6345604472972
# self.stream22 меньше нуля:  PPND-DROSND
# Энтальпия внутри ПЕНД стала меньше 0:  -9000.212034066408
# Энтальпия внутри ПЕНД стала меньше 0:  -9000.212034066408
# Энтальпия внутри ПЕНД стала меньше 0:  -9000.212034066408
# Энтальпия внутри ПЕНД стала меньше 0:  -9000.129861288748
# Энтальпия внутри ПЕНД стала меньше 0:  -17829.35102560535
# Энтальпия внутри ПЕНД стала меньше 0:  -24456.56385475503
# Энтальпия внутри ПЕНД стала меньше 0:  -33164.878889559746
# Энтальпия внутри ПЕНД стала меньше 0:  -39650.600135957095
# Энтальпия внутри ПЕНД стала меньше 0:  -43271.33027530638
# Энтальпия внутри ПЕНД стала меньше 0:  -44289.96972337491
# self.stream22 меньше нуля:  PPND-DROSND
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  71.955
# Энтальпия внутри ПЕНД стала меньше 0:  -139.63555826544598
# Энтальпия внутри ПЕНД стала меньше 0:  -268.3795985143511
# Энтальпия внутри ПЕНД стала меньше 0:  -1146.5492603812277
# Энтальпия внутри ПЕНД стала меньше 0:  -1451.2281883055857
# Энтальпия внутри ПЕНД стала меньше 0:  -1570.135829631934
# self.stream22 меньше нуля:  PPND-DROSND
# Энтальпия внутри ПЕНД стала меньше 0:  -7451.363951515252
# Энтальпия внутри ПЕНД стала меньше 0:  -7451.363951515252
# Энтальпия внутри ПЕНД стала меньше 0:  -7451.363951515252
# Энтальпия внутри ПЕНД стала меньше 0:  -7451.292598462596
# Энтальпия внутри ПЕНД стала меньше 0:  -15117.966494155342
# Энтальпия внутри ПЕНД стала меньше 0:  -20872.572424158512
# Энтальпия внутри ПЕНД стала меньше 0:  -28434.26387398456
# Энтальпия внутри ПЕНД стала меньше 0:  -34066.01334473638
# Энтальпия внутри ПЕНД стала меньше 0:  -37210.00626662299
# Энтальпия внутри ПЕНД стала меньше 0:  -38094.52379328967
# self.stream22 меньше нуля:  PPND-DROSND
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  71.892
# Энтальпия внутри ПЕНД стала меньше 0:  -139.63558237204052
# Энтальпия внутри ПЕНД стала меньше 0:  -268.3796270669218
# Энтальпия внутри ПЕНД стала меньше 0:  -1146.5493147289317
# Энтальпия внутри ПЕНД стала меньше 0:  -1451.228258220252
# Энтальпия внутри ПЕНД стала меньше 0:  -1570.1359086613643
# self.stream22 меньше нуля:  PPND-DROSND
# Энтальпия внутри ПЕНД стала меньше 0:  -7433.084792088095
# Энтальпия внутри ПЕНД стала меньше 0:  -7433.084792088095
# Энтальпия внутри ПЕНД стала меньше 0:  -7433.084792088095
# Энтальпия внутри ПЕНД стала меньше 0:  -7433.013566725511
# Энтальпия внутри ПЕНД стала меньше 0:  -15085.967080327287
# Энтальпия внутри ПЕНД стала меньше 0:  -20830.27472134045
# Энтальпия внутри ПЕНД стала меньше 0:  -28378.433872751244
# Энтальпия внутри ПЕНД стала меньше 0:  -34000.104930347974
# Энтальпия внутри ПЕНД стала меньше 0:  -37138.47148989446
# Энтальпия внутри ПЕНД стала меньше 0:  -38021.40614011041
# self.stream22 меньше нуля:  PPND-DROSND
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  71.891
# Время 6 итерации расчета КУ+ТУ:---  510.2 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.008439618525411356, 0.008431249293499463, 0.008370486168370403, 0.008339966778237135]
# Погрешность давления в верхнем сетевом отборе в %:  0.092
# Энтальпия внутри ПЕНД стала меньше 0:  -937.0273240346405
# Энтальпия внутри ПЕНД стала меньше 0:  -1018.3636243952278
# Энтальпия внутри ПЕНД стала меньше 0:  -2104.1495408529486
# Энтальпия внутри ПЕНД стала меньше 0:  -2446.5455284781406
# Энтальпия внутри ПЕНД стала меньше 0:  -2575.8327795976643
# self.stream22 меньше нуля:  PPND-DROSND
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  73.582
# Энтальпия внутри ПЕНД стала меньше 0:  -842.9869560494681
# Энтальпия внутри ПЕНД стала меньше 0:  -927.4375354297408
# Энтальпия внутри ПЕНД стала меньше 0:  -1982.0554084399027
# Энтальпия внутри ПЕНД стала меньше 0:  -2315.090159624251
# Энтальпия внутри ПЕНД стала меньше 0:  -2440.2832589290847
# self.stream22 меньше нуля:  PPND-DROSND
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  73.492
# Время 7 итерации расчета КУ+ТУ:---  658.3 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Энтальпия внутри ПЕНД стала меньше 0:  -160.97339046388106
# Энтальпия внутри ПЕНД стала меньше 0:  -123.78871834474512
# Энтальпия внутри ПЕНД стала меньше 0:  -81.81420000095159
# self.stream22 меньше нуля:  PPND-DROSND
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  73.191
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.005869490907887446, 0.005823506245203434, 0.005782937695862251, 0.005809658458711711]
# Погрешность давления в верхнем сетевом отборе в %:  -0.08
# Энтальпия внутри ПЕНД стала меньше 0:  -165.0147930297171
# Энтальпия внутри ПЕНД стала меньше 0:  -127.92403481162546
# Энтальпия внутри ПЕНД стала меньше 0:  -86.05277907769869
# self.stream22 меньше нуля:  PPND-DROSND
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  73.202
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Энтальпия внутри ПЕНД стала меньше 0:  -165.76133685656077
# Энтальпия внутри ПЕНД стала меньше 0:  -128.68782540010397
# Энтальпия внутри ПЕНД стала меньше 0:  -86.83553225377318
# self.stream22 меньше нуля:  PPND-DROSND
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  73.204
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Энтальпия внутри ПЕНД стала меньше 0:  -165.70431405811678
# Энтальпия внутри ПЕНД стала меньше 0:  -128.6294833372931
# Энтальпия внутри ПЕНД стала меньше 0:  -86.77573664785905
# self.stream22 меньше нуля:  PPND-DROSND
# Достигнуто максимальное количество итераций котла-утилизатора:4
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0, 0, 0, 0]
# Невозможно получить необходимое давление, диафрагма полностью открыта
# Погрешность давления в верхнем сетевом отборе в %:  73.204
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 8
# Время 8 итерации расчета КУ+ТУ:---  1044.3 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 8
# Pnd_it [0.66481, 0.66681, 0.63619, 0.63013, 0.59813, 0.70136, 0.72848, 0.74163, 0.74626]
# Pvd_it [7.12146, 7.00193, 6.95731, 6.92833, 8.60484, 9.35532, 9.68465, 9.83996, 9.91518]
# Max_error_P 1.5287832632585943
# Max_error_G 1.6403756895173947
# fin КУ и ТУ:--- 1044.3 сек. ---
# Началась 6 итерация расчета ПГУ: --- 1175.2 сек. ---
# n_GTU:  [0, -1, 0.9, 0.99998, 1.09995, 1.09282, 1.09674]
# Delta_n_GTU:  0.357422907890671
# Мощность больше 1 у ГТУ
# 377.06246187048646 h_accum
# 0.1 self._P_accum
# 90.0 self._T_accum
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Время 1 итерации расчета КУ+ТУ:---  17.8 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:3
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.030124941128542505, 0.03007835454379573, 0.02889946864433878, 0.027855978404730346]
# Расход в конденсатор равен нулю
