# %%
from multiprocessing import Pool

import ASWmultiprocess as PC

if __name__ == "__main__":
    
    # "Кнопки"
#     t_air_list = [-29,-15, 0, 8, 15] # - температуры, при которых необходимо расчитать
    t_air_list = [8] # - температуры, при которых необходимо расчитать
#     t_air_list = [-29] # - температуры, при которых необходимо расчитать
    s = len(t_air_list)# - длина списка температур
    nagr_list = 1# -нагрузки, при которых необходимо расчитать
    multic = False
    # Флаги
    ASWbul = [0] #- 0- нет аккум 1- загрузка аккумулятора, 2- разгрузка аккумулятора
    sn = len(ASWbul)
    ASWatm = [True]  #- True- атмосферный аккум False- аккум под давлением

    sq = len(ASWatm)
    PKM_zaryad = False
    # Сalculate_minimum = [False,True]
    Сalculate_minimum = [True]
    sz = len(Сalculate_minimum)
    Teplo = int(True)
    # Вкл выкл заряд по ПКМ
#     PKM_zaryad = False
    
    #ASW konstruct parametr
    Diametr = 5
    Visota=8
    kolichestvo=[1,2,3,4]
    sk = len(kolichestvo)
    lambda_min_vata = 0.045
    delta_min_vata = 0.1
    vremya=4
    vremyaojidaniya = 12

    # Основные эффективности оборудования
    KPD_PN = 0.8074
    KPD_KN = 0.75
    KPD_to = 0.99
    KPD_SP = 0.99

    # Параметры, отвечающие за процесс расчета
    Calcmethod = "hybr"
    Calctolerance = 10**-2
    Maxiterations_KU_TU = 10
    Maxiterations_cotel = 4
    Maxiterations_turbine = 20   
    
    steamVD_fraction_to_turbine=1
    
    chunks = (
                    Diametr,  # Diametr - диаметр аккумулятора
                    kolichestvo[0],  # kolichestvo -  количество баков аккумуляторов
                    Visota,  # Visota - высота аккумулятора
                    lambda_min_vata,  # - lambda_min_vata теплопроводность изолятора бака аккумулятора
                    delta_min_vata,  # - delta_min_vata толщина изолятора бака аккумулятора
                    ASWbul[0],  # ASWbul - 1- загрузка аккумулятора, 2- разгрузка аккумулятора
                    nagr_list,  # nagr - доля нагрузки от номинала
                    vremya,  # vremya - время зарядки/разрядки аккумулятора
                    vremyaojidaniya,  # vremyaojidaniya - время ожидания аккумулятора
                    t_air_list[0],
                    PKM_zaryad,
                    Сalculate_minimum[0],
                    KPD_PN,
                    KPD_KN,
                    KPD_to,
                    KPD_SP,
                    Calcmethod,
                    Calctolerance,
                    Maxiterations_KU_TU,
                    Maxiterations_cotel,
                    Maxiterations_turbine,
                    Сalculate_minimum[0],
                    Teplo,
                    steamVD_fraction_to_turbine,
                    PKM_zaryad,
                    ASWatm[0],
                )
    if multic:
        
    #####################
        for k in range(sk):

            print("Начался расчет kolichestvo=", kolichestvo[k])
            chunks = [
                (
                    Diametr,  # Diametr - диаметр аккумулятора
                    kolichestvo[k],  # kolichestvo -  количество баков аккумуляторов
                    Visota,  # Visota - высота аккумулятора
                    lambda_min_vata,  # - lambda_min_vata теплопроводность изолятора бака аккумулятора
                    delta_min_vata,  # - delta_min_vata толщина изолятора бака аккумулятора
                    ASWbul[i],  # ASWbul - 1- загрузка аккумулятора, 2- разгрузка аккумулятора
                    nagr_list,  # nagr - доля нагрузки от номинала
                    vremya,  # vremya - время зарядки/разрядки аккумулятора
                    vremyaojidaniya,  # vremyaojidaniya - время ожидания аккумулятора
                    t_air_list[j],
                    PKM_zaryad,
                    Сalculate_minimum[z],
                    KPD_PN,
                    KPD_KN,
                    KPD_to,
                    KPD_SP,
                    Calcmethod,
                    Calctolerance,
                    Maxiterations_KU_TU,
                    Maxiterations_cotel,
                    Maxiterations_turbine,
                    Сalculate_minimum[z],
                    Teplo,
                    steamVD_fraction_to_turbine,
                    PKM_zaryad,
                    ASWatm[q],
                )
                for i in range(sn)
                for j in range(s)
                for z in range(sz)
                for q in range(sq)
            ]

            with Pool(60) as pool:
                all_results = pool.map(PC.ParallelCompute, chunks,chunksize=1)
                import pandas as pd
                import openpyxl
                import os
                print(all_results)
                df = pd.DataFrame(all_results)
                pool.close()
                pool.join()
        #         df = df.Thfgh

                if kolichestvo[k]==1:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='140m3',index = False)
                if kolichestvo[k]==2:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='250m3',index = False)
                if kolichestvo[k]==3:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='400m3',index = False)
                if kolichestvo[k]==4:
                    with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                        df.to_excel(writer, sheet_name='565m3',index = False)
        
    else:
        print("Soloraschet")
        PC.ParallelCompute(chunks)
        if kolichestvo[k]==1:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='140m3',index = False)
        if kolichestvo[k]==2:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='250m3',index = False)
        if kolichestvo[k]==3:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='400m3',index = False)
        if kolichestvo[k]==4:
            with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                df.to_excel(writer, sheet_name='565m3',index = False)
# Out:
# Soloraschet
# 1.0 check
# SWIN-TURB G 750.0
# Началась 1 итерация расчета ПГУ: --- 0.0 сек. ---
# n_GTU:  [0.5, 1]
# Delta_n_GTU:  100
# Delta_min:  1.0
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 3
# Время 1 итерации расчета КУ+ТУ:---  11.1 сек. ---
# Достигнуто максимальное количество итераций котла-утилизатора:2
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.005554398763796682, 0.012341551464395025, 0.01849975267208566, 0.015378352252168078]
# Погрешность давления в верхнем сетевом отборе в %:  9.364
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.01331967231042017, 0.012365117443696212, 0.012769247058164535, 0.013487074513748825]
# Погрешность давления в верхнем сетевом отборе в %:  -2.153
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.013170226409766153, 0.01361407821745801, 0.014020691558894651, 0.013839650101859401]
# Погрешность давления в верхнем сетевом отборе в %:  0.543
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 3
# Время 2 итерации расчета КУ+ТУ:---  58.2 сек. ---
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.013132744656209958, 0.013190432696073527, 0.013616033004682768, 0.01398874638396266]
# Погрешность давления в верхнем сетевом отборе в %:  -1.118
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.013347558261834102, 0.013057569677667151, 0.013402816433739532, 0.013458710430981527]
# Погрешность давления в верхнем сетевом отборе в %:  -0.168
# Время 3 итерации расчета КУ+ТУ:---  81.3 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 3
# Pnd_it [0.63975, 0.80819, 0.78818, 0.77765]
# Pvd_it [7.87743, 7.17879, 6.9587, 6.87069]
# Max_error_P 2.672725849152547
# Max_error_G 0.031190943513630436
# fin КУ и ТУ:--- 81.3 сек. ---
# Началась 2 итерация расчета ПГУ: --- 81.5 сек. ---
# n_GTU:  [0.5, 1, 0.9]
# Delta_n_GTU:  11.111111111111107
# Delta_min:  1.0
# Время 1 итерации расчета КУ+ТУ:---  10.2 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.021665987299347895, 0.021628351372128932, 0.02184609110616393, 0.022050692750717388]
# Погрешность давления в верхнем сетевом отборе в %:  -0.614
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.021498388782953775, 0.021681745062349923, 0.022227967585242567, 0.022429488400319508]
# Погрешность давления в верхнем сетевом отборе в %:  -0.605
# Время 2 итерации расчета КУ+ТУ:---  40.8 сек. ---
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.02184588447143221, 0.02175413106694892, 0.0214428271072245, 0.021313440082087753]
# Погрешность давления в верхнем сетевом отборе в %:  0.388
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 3 итерации расчета КУ+ТУ:---  62.7 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 3
# Pnd_it [0.77765, 0.78009, 0.74594, 0.73525]
# Pvd_it [6.87069, 6.69802, 6.63123, 6.59551]
# Max_error_P 2.8680368739742423
# Max_error_G 0.04488871227134011
# fin КУ и ТУ:--- 62.7 сек. ---
# Началась 3 итерация расчета ПГУ: --- 144.5 сек. ---
# n_GTU:  [0.5, 1, 0.9, 0.83439]
# Delta_n_GTU:  7.863229425088994
# Delta_min:  0.6561368932365967
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 3
# Время 1 итерации расчета КУ+ТУ:---  10.1 сек. ---
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.019272962034888718, 0.019074703363795204, 0.01896842276135136, 0.01911348924058815]
# Погрешность давления в верхнем сетевом отборе в %:  -0.435
# Время 2 итерации расчета КУ+ТУ:---  41.9 сек. ---
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.019708911720698653, 0.020139084349079715, 0.01986700520469059, 0.019609894317133822]
# Погрешность давления в верхнем сетевом отборе в %:  0.771
# Время 3 итерации расчета КУ+ТУ:---  65.6 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 3
# Pnd_it [0.73525, 0.76871, 0.74685, 0.74128]
# Pvd_it [6.59551, 6.61836, 6.63388, 6.6329]
# Max_error_P 1.4920745641510793
# Max_error_G 0.04132619674357189
# fin КУ и ТУ:--- 65.6 сек. ---
# Началась 4 итерация расчета ПГУ: --- 210.4 сек. ---
# n_GTU:  [0.5, 1, 0.9, 0.83439, 0.85115]
# Delta_n_GTU:  1.969100628561358
# Delta_min:  -0.1676856149145911
# Время 1 итерации расчета КУ+ТУ:---  6.1 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 2 итерации расчета КУ+ТУ:---  33.1 сек. ---
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.019608352450676516, 0.01943640480139589, 0.019725188943157942, 0.020129834595735297]
# Погрешность давления в верхнем сетевом отборе в %:  -1.214
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 3 итерации расчета КУ+ТУ:---  50.6 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 3
# Pnd_it [0.74128, 0.77012, 0.7462, 0.73955]
# Pvd_it [6.6329, 6.62575, 6.62946, 6.6233]
# Max_error_P 1.7812514447752874
# Max_error_G 0.09002455433026213
# fin КУ и ТУ:--- 50.6 сек. ---
# Началась 5 итерация расчета ПГУ: --- 261.4 сек. ---
# n_GTU:  [0.5, 1, 0.9, 0.83439, 0.85115, 0.84755]
# Delta_n_GTU:  0.4247537018464913
# Delta_min:  0.03601562885007476
# Время 1 итерации расчета КУ+ТУ:---  6.7 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 2 итерации расчета КУ+ТУ:---  35.9 сек. ---
# Время 3 итерации расчета КУ+ТУ:---  54.9 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 3
# Pnd_it [0.73955, 0.76949, 0.74603, 0.74014]
# Pvd_it [6.6233, 6.62361, 6.631, 6.62642]
# Max_error_P 1.579356029656216
# Max_error_G 0.03161565844095811
# fin КУ и ТУ:--- 54.9 сек. ---
# Началась 6 итерация расчета ПГУ: --- 316.5 сек. ---
# n_GTU:  [0.5, 1, 0.9, 0.83439, 0.85115, 0.84755, 0.84876]
# Delta_n_GTU:  0.14256091238983146
# Delta_min:  -0.012062389257494376
# Время 1 итерации расчета КУ+ТУ:---  2.6 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.019995511962437054, 0.019826151515055363, 0.020105718760499106, 0.020501308213414407]
# Погрешность давления в верхнем сетевом отборе в %:  -1.187
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 3
# Время 2 итерации расчета КУ+ТУ:---  26.4 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 3
# Время 3 итерации расчета КУ+ТУ:---  51.3 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 3
# Pnd_it [0.74014, 0.76552, 0.74493, 0.73948]
# Pvd_it [6.62642, 6.62533, 6.62921, 6.62327]
# Max_error_P 1.4636919183048027
# Max_error_G 0.16973475660205609
# fin КУ и ТУ:--- 51.3 сек. ---
# Началась 7 итерация расчета ПГУ: --- 368.1 сек. ---
# n_GTU:  [0.5, 1, 0.9, 0.83439, 0.85115, 0.84755, 0.84876, 0.84771]
# Delta_n_GTU:  0.12386311356477987
# Delta_min:  0.010455918753380285
# Время 1 итерации расчета КУ+ТУ:---  2.6 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.01998863211622912, 0.019812439463701804, 0.020099666535479316, 0.020508568126112316]
# Погрешность давления в верхнем сетевом отборе в %:  -1.227
# Время 2 итерации расчета КУ+ТУ:---  25.9 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Достигнуто максимальное количество итераций расхода КУ+ПТУ: 3
# Время 3 итерации расчета КУ+ТУ:---  47.4 сек. ---
# Достигнуто максимальное количество итераций давления КУ+ПТУ: 3
# Pnd_it [0.73948, 0.76528, 0.74483, 0.73946]
# Pvd_it [6.62327, 6.62433, 6.62881, 6.62314]
# Max_error_P 1.4419216990239632
# Max_error_G 0.16943287324445658
# fin КУ и ТУ:--- 47.4 сек. ---
# Началась 8 итерация расчета ПГУ: --- 415.8 сек. ---
# n_GTU:  [0.5, 1, 0.9, 0.83439, 0.85115, 0.84755, 0.84876, 0.84771, 0.84773]
# Delta_n_GTU:  0.0023592417397072184
# Delta_min:  -0.0002064814945000191
# Время 1 итерации расчета КУ+ТУ:---  7.9 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 2 итерации расчета КУ+ТУ:---  41.8 сек. ---
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Время 3 итерации расчета КУ+ТУ:---  70.1 сек. ---
# Давление на входе в ЦНД меньше нуля при температуре воздуха: 8.0
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.029690977766627623, 0.02929052672979651, 0.02837958478293264, 0.027985567083906447]
# Расход в конденсатор равен нулю
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.027864559496187977, 0.029319363922057893, 0.03026217852771958, 0.0295828801842807]
# Расход в конденсатор равен нулю
# Время 4 итерации расчета КУ+ТУ:---  135.5 сек. ---
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.028966897386058177, 0.02672653239592071, 0.02599506399779196, 0.027685136595516864]
# Погрешность давления в верхнем сетевом отборе в %:  -5.07
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.027840177494725473, 0.02849595368995134, 0.028722835510857532, 0.028243907330238138]
# Погрешность давления в верхнем сетевом отборе в %:  1.437
# Достигнуто максимальное количество итераций давления верхнего отбора
# Diafragma_it [0.02798172265261825, 0.028031090158830454, 0.028153709072107975, 0.028074212072815446]
# Погрешность давления в верхнем сетевом отборе в %:  0.238
# Время 5 итерации расчета КУ+ТУ:---  206.6 сек. ---
