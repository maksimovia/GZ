# %%
from multiprocessing import Pool

import ASWmultiprocess as PC

if __name__ == "__main__":
    
    # "Кнопки"
#     t_air_list = [-29,-15, 0, 8, 15] # - температуры, при которых необходимо расчитать
    t_air_list = [-29, -25, -20, -15, -10, -5, 0, 5, 8] # - температуры, при которых необходимо расчитать
#     t_air_list = [-29] # - температуры, при которых необходимо расчитать
    s = len(t_air_list)# - длина списка температур
    nagr_list = 1# -нагрузки, при которых необходимо расчитать

    # Флаги
    ASWbul = [0,1,2] #- 0- нет аккум 1- загрузка аккумулятора, 2- разгрузка аккумулятора
    sn = len(ASWbul)
    ASWatm = [False,True]  #- True- атмосферный аккум False- аккум под давлением

    sq = len(ASWatm)
    PKM_zaryad = False
    Сalculate_minimum = [False,True]
    # Сalculate_minimum = [True]
    sz = len(Сalculate_minimum)
    Teplo = int(True)
    # Вкл выкл заряд по ПКМ
#     PKM_zaryad = False
    
    #ASW konstruct parametr
    Diametr = 5
    Visota=8
    kolichestvo=[1,2,3,4]
    sk = len(kolichestvo)
    lambda_min_vata = 0.045
    delta_min_vata = 0.1
    vremya=4
    vremyaojidaniya = 12

    # Основные эффективности оборудования
    KPD_PN = 0.8074
    KPD_KN = 0.75
    KPD_to = 0.99
    KPD_SP = 0.99

    # Параметры, отвечающие за процесс расчета
    Calcmethod = "hybr"
    Calctolerance = 10**-2
    Maxiterations_KU_TU = 8
    Maxiterations_cotel = 5
    Maxiterations_turbine = 25   
    
    steamVD_fraction_to_turbine=1


    #####################
    for k in range(sk):
        
        print("Начался расчет kolichestvo=", kolichestvo[k])
        chunks = [
            (
                Diametr,  # Diametr - диаметр аккумулятора
                kolichestvo[k],  # kolichestvo -  количество баков аккумуляторов
                Visota,  # Visota - высота аккумулятора
                lambda_min_vata,  # - lambda_min_vata теплопроводность изолятора бака аккумулятора
                delta_min_vata,  # - delta_min_vata толщина изолятора бака аккумулятора
                ASWbul[i],  # ASWbul - 1- загрузка аккумулятора, 2- разгрузка аккумулятора
                nagr_list,  # nagr - доля нагрузки от номинала
                vremya,  # vremya - время зарядки/разрядки аккумулятора
                vremyaojidaniya,  # vremyaojidaniya - время ожидания аккумулятора
                t_air_list[j],
                PKM_zaryad,
                Сalculate_minimum[z],
                KPD_PN,
                KPD_KN,
                KPD_to,
                KPD_SP,
                Calcmethod,
                Calctolerance,
                Maxiterations_KU_TU,
                Maxiterations_cotel,
                Maxiterations_turbine,
                Сalculate_minimum[z],
                Teplo,
                steamVD_fraction_to_turbine,
                PKM_zaryad,
                ASWatm[q],
            )
            for i in range(sn)
            for j in range(s)
            for z in range(sz)
            for q in range(sq)
        ]

        with Pool(50) as pool:
            all_results = pool.map(PC.ParallelCompute, chunks,chunksize=1)
            import pandas as pd
            import openpyxl
            import os
            print(all_results)
            df = pd.DataFrame(all_results)
            pool.close()
            pool.join()
    #         df = df.Thfgh

            if kolichestvo[k]==1:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='140m3',index = False)
            if kolichestvo[k]==2:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='250m3',index = False)
            if kolichestvo[k]==3:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='400m3',index = False)
            if kolichestvo[k]==4:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='565m3',index = False)
# Out:
# Начался расчет kolichestvo= 1
# [{'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5127, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1189, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.157, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 349.6131432056427}, {'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5127, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1189, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.157, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 351.54470348358154}, {'T_air': -29, 'n_GTU': 0.85986, 'GTU': 142.4449, 'GTU_KPD': 32.7711, 'Turbine': 42.9776, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6174, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.3882, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 642.9956479072571}, {'T_air': -29, 'n_GTU': 0.85986, 'GTU': 142.4449, 'GTU_KPD': 32.7711, 'Turbine': 42.9776, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6174, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.3882, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 641.2540826797485}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3814, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0296, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 7.7916, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 364.72489833831787}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3814, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0296, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 7.7916, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 364.3052656650543}, {'T_air': -25, 'n_GTU': 0.91771, 'GTU': 152.0277, 'GTU_KPD': 33.5356, 'Turbine': 45.2438, 'KN': 0.0403, 'DK': 6.2725, 'PEN': 2.0227, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4346, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1610.9257748126984}, {'T_air': -25, 'n_GTU': 0.91771, 'GTU': 152.0277, 'GTU_KPD': 33.5356, 'Turbine': 45.2438, 'KN': 0.0403, 'DK': 6.2725, 'PEN': 2.0227, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4346, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1616.0596480369568}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1182, 'KN': 0.0565, 'DK': 6.3014, 'PEN': 0.9159, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 6.2152, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 306.77956891059875}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1182, 'KN': 0.0565, 'DK': 6.3014, 'PEN': 0.9159, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 6.2152, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 306.47956705093384}, {'T_air': -20, 'n_GTU': 0.95733, 'GTU': 158.5907, 'GTU_KPD': 33.9203, 'Turbine': 48.4761, 'KN': 0.0403, 'DK': 6.2864, 'PEN': 1.3552, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4348, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1585.7134139537811}, {'T_air': -20, 'n_GTU': 0.95733, 'GTU': 158.5907, 'GTU_KPD': 33.9203, 'Turbine': 48.4761, 'KN': 0.0403, 'DK': 6.2864, 'PEN': 1.3552, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4348, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1588.928973197937}, {'T_air': -15, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0948, 'Turbine': 52.8252,  ...
# Начался расчет kolichestvo= 2
# [{'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5127, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1189, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.157, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 351.2176413536072}, {'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5127, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1189, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.157, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 352.67924213409424}, {'T_air': -29, 'n_GTU': 0.85986, 'GTU': 142.4449, 'GTU_KPD': 32.7711, 'Turbine': 42.9776, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6174, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.3882, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 641.3911762237549}, {'T_air': -29, 'n_GTU': 0.85986, 'GTU': 142.4449, 'GTU_KPD': 32.7711, 'Turbine': 42.9776, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6174, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.3882, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 636.718094587326}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3814, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0296, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 7.7916, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 365.90277910232544}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3814, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0296, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 7.7916, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 364.0611653327942}, {'T_air': -25, 'n_GTU': 0.91771, 'GTU': 152.0277, 'GTU_KPD': 33.5356, 'Turbine': 45.2438, 'KN': 0.0403, 'DK': 6.2725, 'PEN': 2.0227, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4346, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1527.3192486763}, {'T_air': -25, 'n_GTU': 0.91771, 'GTU': 152.0277, 'GTU_KPD': 33.5356, 'Turbine': 45.2438, 'KN': 0.0403, 'DK': 6.2725, 'PEN': 2.0227, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4346, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1524.7292149066925}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1182, 'KN': 0.0565, 'DK': 6.3014, 'PEN': 0.9159, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 6.2152, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 307.69729495048523}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1182, 'KN': 0.0565, 'DK': 6.3014, 'PEN': 0.9159, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 6.2152, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 308.0572998523712}, {'T_air': -20, 'n_GTU': 0.95733, 'GTU': 158.5907, 'GTU_KPD': 33.9203, 'Turbine': 48.4761, 'KN': 0.0403, 'DK': 6.2864, 'PEN': 1.3552, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4348, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1508.5460412502289}, {'T_air': -20, 'n_GTU': 0.95733, 'GTU': 158.5907, 'GTU_KPD': 33.9203, 'Turbine': 48.4761, 'KN': 0.0403, 'DK': 6.2864, 'PEN': 1.3552, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4348, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1509.7275032997131}, {'T_air': -15, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0948, 'Turbine': 52.8252, 'KN' ...
# Начался расчет kolichestvo= 3
# [{'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5127, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1189, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.157, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 325.73511242866516}, {'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5127, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1189, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.157, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 324.28509545326233}, {'T_air': -29, 'n_GTU': 0.85986, 'GTU': 142.4449, 'GTU_KPD': 32.7711, 'Turbine': 42.9776, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6174, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.3882, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 589.8936545848846}, {'T_air': -29, 'n_GTU': 0.85986, 'GTU': 142.4449, 'GTU_KPD': 32.7711, 'Turbine': 42.9776, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6174, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.3882, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 588.9836447238922}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3814, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0296, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 7.7916, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 339.60255908966064}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3814, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0296, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 7.7916, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 331.7624657154083}, {'T_air': -25, 'n_GTU': 0.91771, 'GTU': 152.0277, 'GTU_KPD': 33.5356, 'Turbine': 45.2438, 'KN': 0.0403, 'DK': 6.2725, 'PEN': 2.0227, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4346, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1492.3920226097107}, {'T_air': -25, 'n_GTU': 0.91771, 'GTU': 152.0277, 'GTU_KPD': 33.5356, 'Turbine': 45.2438, 'KN': 0.0403, 'DK': 6.2725, 'PEN': 2.0227, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4346, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1492.6220254898071}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1182, 'KN': 0.0565, 'DK': 6.3014, 'PEN': 0.9159, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 6.2152, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 283.44977474212646}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1182, 'KN': 0.0565, 'DK': 6.3014, 'PEN': 0.9159, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 6.2152, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 283.02976965904236}, {'T_air': -20, 'n_GTU': 0.95733, 'GTU': 158.5907, 'GTU_KPD': 33.9203, 'Turbine': 48.4761, 'KN': 0.0403, 'DK': 6.2864, 'PEN': 1.3552, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4348, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1466.306198835373}, {'T_air': -20, 'n_GTU': 0.95733, 'GTU': 158.5907, 'GTU_KPD': 33.9203, 'Turbine': 48.4761, 'KN': 0.0403, 'DK': 6.2864, 'PEN': 1.3552, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4348, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1473.4262835979462}, {'T_air': -15, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0948, 'Turbine': 52.8252, ...
# Начался расчет kolichestvo= 4
# [{'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5127, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1189, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.157, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 331.1832711696625}, {'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5127, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1189, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.157, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 331.8832776546478}, {'T_air': -29, 'n_GTU': 0.85986, 'GTU': 142.4449, 'GTU_KPD': 32.7711, 'Turbine': 42.9776, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6174, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.3882, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 606.8527450561523}, {'T_air': -29, 'n_GTU': 0.85986, 'GTU': 142.4449, 'GTU_KPD': 32.7711, 'Turbine': 42.9776, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6174, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.3882, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 606.4927411079407}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3814, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0296, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 7.7916, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 346.33217906951904}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3814, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0296, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 7.7916, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 344.1343905925751}, {'T_air': -25, 'n_GTU': 0.91771, 'GTU': 152.0277, 'GTU_KPD': 33.5356, 'Turbine': 45.2438, 'KN': 0.0403, 'DK': 6.2725, 'PEN': 2.0227, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4346, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1536.648306131363}, {'T_air': -25, 'n_GTU': 0.91771, 'GTU': 152.0277, 'GTU_KPD': 33.5356, 'Turbine': 45.2438, 'KN': 0.0403, 'DK': 6.2725, 'PEN': 2.0227, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4346, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1533.9382734298706}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1182, 'KN': 0.0565, 'DK': 6.3014, 'PEN': 0.9159, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 6.2152, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 290.22114610671997}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1182, 'KN': 0.0565, 'DK': 6.3014, 'PEN': 0.9159, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 6.2152, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 290.40114760398865}, {'T_air': -20, 'n_GTU': 0.95733, 'GTU': 158.5907, 'GTU_KPD': 33.9203, 'Turbine': 48.4761, 'KN': 0.0403, 'DK': 6.2864, 'PEN': 1.3552, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4348, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1517.272742986679}, {'T_air': -20, 'n_GTU': 0.95733, 'GTU': 158.5907, 'GTU_KPD': 33.9203, 'Turbine': 48.4761, 'KN': 0.0403, 'DK': 6.2864, 'PEN': 1.3552, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.4348, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1513.0426931381226}, {'T_air': -15, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0948, 'Turbine': 52.8252, 'K ...
