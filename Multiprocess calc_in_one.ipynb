# %%
from multiprocessing import Pool

import ASWmultiprocess as PC

if __name__ == "__main__":
    
    # "Кнопки"
#     t_air_list = [-29,-15, 0, 8, 15] # - температуры, при которых необходимо расчитать
    t_air_list = [-29, -25, -20, -15, -10, -5, 0, 5, 8] # - температуры, при которых необходимо расчитать
#     t_air_list = [-29] # - температуры, при которых необходимо расчитать
    s = len(t_air_list)# - длина списка температур
    nagr_list = 1# -нагрузки, при которых необходимо расчитать

    # Флаги
    ASWbul = [0,1,2] #- 0- нет аккум 1- загрузка аккумулятора, 2- разгрузка аккумулятора
    sn = len(ASWbul)
    ASWatm = [False,True]  #- True- атмосферный аккум False- аккум под давлением

    sq = len(ASWatm)
    PKM_zaryad = False
    Сalculate_minimum = [False,True]
    # Сalculate_minimum = [True]
    sz = len(Сalculate_minimum)
    Teplo = int(True)
    # Вкл выкл заряд по ПКМ
#     PKM_zaryad = False
    
    #ASW konstruct parametr
    Diametr = 5
    Visota=8
    kolichestvo=[1,2,3,4]
    sk = len(kolichestvo)
    lambda_min_vata = 0.045
    delta_min_vata = 0.1
    vremya=4
    vremyaojidaniya = 12

    # Основные эффективности оборудования
    KPD_PN = 0.8074
    KPD_KN = 0.75
    KPD_to = 0.99
    KPD_SP = 0.99

    # Параметры, отвечающие за процесс расчета
    Calcmethod = "hybr"
    Calctolerance = 10**-2
    Maxiterations_KU_TU = 8
    Maxiterations_cotel = 5
    Maxiterations_turbine = 25   
    
    steamVD_fraction_to_turbine=1


    #####################
    for k in range(sk):
        
        print("Начался расчет kolichestvo=", kolichestvo[k])
        chunks = [
            (
                Diametr,  # Diametr - диаметр аккумулятора
                kolichestvo[k],  # kolichestvo -  количество баков аккумуляторов
                Visota,  # Visota - высота аккумулятора
                lambda_min_vata,  # - lambda_min_vata теплопроводность изолятора бака аккумулятора
                delta_min_vata,  # - delta_min_vata толщина изолятора бака аккумулятора
                ASWbul[i],  # ASWbul - 1- загрузка аккумулятора, 2- разгрузка аккумулятора
                nagr_list,  # nagr - доля нагрузки от номинала
                vremya,  # vremya - время зарядки/разрядки аккумулятора
                vremyaojidaniya,  # vremyaojidaniya - время ожидания аккумулятора
                t_air_list[j],
                PKM_zaryad,
                Сalculate_minimum[z],
                KPD_PN,
                KPD_KN,
                KPD_to,
                KPD_SP,
                Calcmethod,
                Calctolerance,
                Maxiterations_KU_TU,
                Maxiterations_cotel,
                Maxiterations_turbine,
                Сalculate_minimum[z],
                Teplo,
                steamVD_fraction_to_turbine,
                PKM_zaryad,
                ASWatm[q],
            )
            for i in range(sn)
            for j in range(s)
            for z in range(sz)
            for q in range(sq)
        ]

        with Pool(50) as pool:
            all_results = pool.map(PC.ParallelCompute, chunks,chunksize=1)
            import pandas as pd
            import openpyxl
            import os
            print(all_results)
            df = pd.DataFrame(all_results)
            pool.close()
            pool.join()
    #         df = df.Thfgh

            if kolichestvo[k]==1:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='140m3',index = False)
            if kolichestvo[k]==2:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='250m3',index = False)
            if kolichestvo[k]==3:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='400m3',index = False)
            if kolichestvo[k]==4:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='565m3',index = False)
# Out:
# Начался расчет kolichestvo= 1
# [{'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5118, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1197, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.1588, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 315.5550763607025}, {'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5118, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1197, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.1588, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 315.0154104232788}, {'T_air': -29, 'n_GTU': 0.85994, 'GTU': 142.4571, 'GTU_KPD': 32.7722, 'Turbine': 42.9763, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6178, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.3875, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 594.8924582004547}, {'T_air': -29, 'n_GTU': 0.85994, 'GTU': 142.4571, 'GTU_KPD': 32.7722, 'Turbine': 42.9763, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6178, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.3875, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 594.7361977100372}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3821, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0294, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 7.792, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 301.363929271698}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3821, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0294, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 7.792, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 303.1780116558075}, {'T_air': -25, 'n_GTU': 0.91639, 'GTU': 151.8091, 'GTU_KPD': 33.5205, 'Turbine': 45.1923, 'KN': 0.0398, 'DK': 6.272, 'PEN': 2.0413, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.3774, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 573.5364363193512}, {'T_air': -25, 'n_GTU': 0.91639, 'GTU': 151.8091, 'GTU_KPD': 33.5205, 'Turbine': 45.1923, 'KN': 0.0398, 'DK': 6.272, 'PEN': 2.0413, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.3774, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 571.3278844356537}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1204, 'KN': 0.0566, 'DK': 6.3014, 'PEN': 0.9154, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 6.2183, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 313.82770133018494}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1204, 'KN': 0.0566, 'DK': 6.3014, 'PEN': 0.9154, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 6.2183, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 316.0162572860718}, {'T_air': -20, 'n_GTU': 0.95735, 'GTU': 158.5949, 'GTU_KPD': 33.9205, 'Turbine': 48.4739, 'KN': 0.0404, 'DK': 6.2864, 'PEN': 1.3566, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.4378, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1394.8933987617493}, {'T_air': -20, 'n_GTU': 0.95735, 'GTU': 158.5949, 'GTU_KPD': 33.9205, 'Turbine': 48.4739, 'KN': 0.0404, 'DK': 6.2864, 'PEN': 1.3566, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.4378, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1396.4653522968292}, {'T_air': -15, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0948, 'Turbine': 52.8241, 'KN ...
# Начался расчет kolichestvo= 2
# [{'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5118, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1197, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.1588, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 320.6655240058899}, {'T_air': -29, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0758, 'Turbine': 48.5118, 'KN': 0.0924, 'DK': 6.3014, 'PEN': 1.1197, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 10.1588, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 322.8300085067749}, {'T_air': -29, 'n_GTU': 0.85994, 'GTU': 142.4571, 'GTU_KPD': 32.7722, 'Turbine': 42.9763, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6178, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.3875, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 603.117803812027}, {'T_air': -29, 'n_GTU': 0.85994, 'GTU': 142.4571, 'GTU_KPD': 32.7722, 'Turbine': 42.9763, 'KN': 0.0399, 'DK': 6.2521, 'PEN': 2.6178, 'Turbine_Qt': 157.0125, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.3875, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 606.050460100174}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3821, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0294, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 7.792, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 307.5605881214142}, {'T_air': -25, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0824, 'Turbine': 48.3821, 'KN': 0.0709, 'DK': 6.3014, 'PEN': 1.0294, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 7.792, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 310.01813864707947}, {'T_air': -25, 'n_GTU': 0.91639, 'GTU': 151.8091, 'GTU_KPD': 33.5205, 'Turbine': 45.1923, 'KN': 0.0398, 'DK': 6.272, 'PEN': 2.0413, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.3774, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 580.047634601593}, {'T_air': -25, 'n_GTU': 0.91639, 'GTU': 151.8091, 'GTU_KPD': 33.5205, 'Turbine': 45.1923, 'KN': 0.0398, 'DK': 6.272, 'PEN': 2.0413, 'Turbine_Qt': 163.607, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': 0.0, 'INKOND': 4.3774, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 581.0048491954803}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1204, 'KN': 0.0566, 'DK': 6.3014, 'PEN': 0.9154, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 6.2183, 'ASWatm': False, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 320.565500497818}, {'T_air': -20, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0912, 'Turbine': 50.1204, 'KN': 0.0566, 'DK': 6.3014, 'PEN': 0.9154, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 6.2183, 'ASWatm': True, 'Calculate_minimum': False, 'G_ASW': 0.0, 'Time to calculate': 317.10472440719604}, {'T_air': -20, 'n_GTU': 0.95735, 'GTU': 158.5949, 'GTU_KPD': 33.9205, 'Turbine': 48.4739, 'KN': 0.0404, 'DK': 6.2864, 'PEN': 1.3566, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.4378, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1405.476175069809}, {'T_air': -20, 'n_GTU': 0.95735, 'GTU': 158.5949, 'GTU_KPD': 33.9205, 'Turbine': 48.4739, 'KN': 0.0404, 'DK': 6.2864, 'PEN': 1.3566, 'Turbine_Qt': 168.3174, 'ASW_Qt': nan, 'ASW_bull': 0, 'Delta_P_Diafragma': -0.0, 'INKOND': 4.4378, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0.0, 'Time to calculate': 1405.5461909770966}, {'T_air': -15, 'n_GTU': 1, 'GTU': 165.66, 'GTU_KPD': 34.0948, 'Turbine': 52.8241, 'KN':  ...
# Начался расчет kolichestvo= 3
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "C:\Users\Admin\Documents\GitHub\GZ\ASWmultiprocess.py", line 334, in ParallelCompute
#     calculate_all.calculate_CCGT(args)
#   File "C:\Users\Admin\Documents\GitHub\GZ\calculate_all.py", line 218, in calculate_CCGT
#     KU_and_TU.calculate(
#   File "C:\Users\Admin\Documents\GitHub\GZ\KU_TU.py", line 131, in calculate
#     TU_res = self.TU.calculate(
#   File "C:\Users\Admin\Documents\GitHub\GZ\Turboustanovka.py", line 156, in calculate
#     Result = self.calculate_t_rejim(
#   File "C:\Users\Admin\Documents\GitHub\GZ\Turboustanovka.py", line 131, in calculate_t_rejim
#     Diafragma = self.Find_Potb2_it(maxiterations, calctolerance)
#   File "C:\Users\Admin\Documents\GitHub\GZ\Turboustanovka.py", line 75, in Find_Potb2_it
#     Turb_res = self.Turb.calculate(
#   File "C:\Users\Admin\Documents\GitHub\GZ\Turbine.py", line 418, in calculate
#     self.calculate_turbine_expansion()
#   File "C:\Users\Admin\Documents\GitHub\GZ\Turbine.py", line 331, in calculate_turbine_expansion
#     self.KPD_ots4 = self.off_design_relative_efficiency_CND(
#   File "C:\Users\Admin\Documents\GitHub\GZ\Turbine.py", line 176, in off_design_relative_efficiency_CND
#     Hteor_out = self.water.p_s(pout, s0)['h']
#   File "C:\Users\Admin\Documents\GitHub\GZ\mat_properties.py", line 234, in p_s
#     return self.__ps_func(p=p*1e6, s=s*1000, gas=self.__mat_name,fraction=self.__fraction, **self.__params)
#   File "C:\Users\Admin\Documents\GitHub\GZ\mat_properties.py", line 153, in REFPROP_p_s
#     res['T'] = CP.PropsSI('T','P', p,'S',s,gas)-273.15
#   File "CoolProp\CoolProp.pyx", line 373, in CoolProp.CoolProp.PropsSI
#   File "CoolProp\CoolProp.pyx", line 469, in CoolProp.CoolProp.PropsSI
#   File "CoolProp\CoolProp.pyx", line 340, in CoolProp.CoolProp.__Props_err2
# ValueError: unable to solve 1phase PY flash with Tmin=273.159, Tmax=296.955 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [-2.48641 J/mol/K] is below the minimum value of -0.000323794731992 J/mol/K : PropsSI("T","P",2951.026721,"S",-138.016853,"water")
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [1], line 94
#      58 chunks = [
#      59     (
#      60         Diametr,  # Diametr - диаметр аккумулятора
#    (...)
#      90     for q in range(sq)
#      91 ]
#      93 with Pool(50) as pool:
# ---> 94     all_results = pool.map(PC.ParallelCompute, chunks,chunksize=1)
#      95     import pandas as pd
#      96     import openpyxl
#
# File ~\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# ValueError: unable to solve 1phase PY flash with Tmin=273.159, Tmax=296.955 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [-2.48641 J/mol/K] is below the minimum value of -0.000323794731992 J/mol/K : PropsSI("T","P",2951.026721,"S",-138.016853,"water")
