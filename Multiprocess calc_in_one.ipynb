# %%
from multiprocessing import Pool

import ASWmultiprocess as PC

if __name__ == "__main__":
    
    # "Кнопки"
#     t_air_list = [-29,-15, 0, 8, 15] # - температуры, при которых необходимо расчитать
    t_air_list = [-5] # - температуры, при которых необходимо расчитать
#     t_air_list = [-29] # - температуры, при которых необходимо расчитать
    s = len(t_air_list)# - длина списка температур
    nagr_list = 1# -нагрузки, при которых необходимо расчитать

    # Флаги
    ASWbul = [1,2] #- 0- нет аккум 1- загрузка аккумулятора, 2- разгрузка аккумулятора
    sn = len(ASWbul)
    ASWatm = [False,True]  #- True- атмосферный аккум False- аккум под давлением

    sq = len(ASWatm)
    PKM_zaryad = False
    # Сalculate_minimum = [False,True]
    Сalculate_minimum = [True]
    sz = len(Сalculate_minimum)
    Teplo = int(True)
    # Вкл выкл заряд по ПКМ
#     PKM_zaryad = False
    
    #ASW konstruct parametr
    Diametr = 5
    Visota=8
    kolichestvo=[1,2,3,4]
    sk = len(kolichestvo)
    lambda_min_vata = 0.045
    delta_min_vata = 0.1
    vremya=4
    vremyaojidaniya = 12

    # Основные эффективности оборудования
    KPD_PN = 0.8074
    KPD_KN = 0.75
    KPD_to = 0.99
    KPD_SP = 0.99

    # Параметры, отвечающие за процесс расчета
    Calcmethod = "hybr"
    Calctolerance = 10**-2
    Maxiterations_KU_TU = 8
    Maxiterations_cotel = 5
    Maxiterations_turbine = 25   
    
    steamVD_fraction_to_turbine=1


    #####################
    for k in range(sk):
        
        print("Начался расчет kolichestvo=", kolichestvo[k])
        chunks = [
            (
                Diametr,  # Diametr - диаметр аккумулятора
                kolichestvo[k],  # kolichestvo -  количество баков аккумуляторов
                Visota,  # Visota - высота аккумулятора
                lambda_min_vata,  # - lambda_min_vata теплопроводность изолятора бака аккумулятора
                delta_min_vata,  # - delta_min_vata толщина изолятора бака аккумулятора
                ASWbul[i],  # ASWbul - 1- загрузка аккумулятора, 2- разгрузка аккумулятора
                nagr_list,  # nagr - доля нагрузки от номинала
                vremya,  # vremya - время зарядки/разрядки аккумулятора
                vremyaojidaniya,  # vremyaojidaniya - время ожидания аккумулятора
                t_air_list[j],
                PKM_zaryad,
                Сalculate_minimum[z],
                KPD_PN,
                KPD_KN,
                KPD_to,
                KPD_SP,
                Calcmethod,
                Calctolerance,
                Maxiterations_KU_TU,
                Maxiterations_cotel,
                Maxiterations_turbine,
                Сalculate_minimum[z],
                Teplo,
                steamVD_fraction_to_turbine,
                PKM_zaryad,
                ASWatm[q],
            )
            for i in range(sn)
            for j in range(s)
            for z in range(sz)
            for q in range(sq)
        ]

        with Pool(60) as pool:
            all_results = pool.map(PC.ParallelCompute, chunks,chunksize=1)
            import pandas as pd
            import openpyxl
            import os
            print(all_results)
            df = pd.DataFrame(all_results)
            pool.close()
            pool.join()
    #         df = df.Thfgh

            if kolichestvo[k]==1:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='140m3',index = False)
            if kolichestvo[k]==2:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='250m3',index = False)
            if kolichestvo[k]==3:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='400m3',index = False)
            if kolichestvo[k]==4:
                with pd.ExcelWriter('resdataASW_all_m3.xlsx',mode='a',engine='openpyxl',if_sheet_exists="replace") as writer:
                    df.to_excel(writer, sheet_name='565m3',index = False)
# Out:
# Начался расчет kolichestvo= 1
# [{'T_air': -5, 'n_GTU': 0.95457, 'GTU': 158.1339, 'GTU_KPD': 33.8698, 'Turbine': 55.6224, 'KN': 0.0404, 'DK': 6.2854, 'PEN': 0.9006, 'Turbine_Qt': 170.097, 'ASW_Qt': 2.3404, 'ASW_bull': 1, 'Delta_P_Diafragma': 0.0531, 'INKOND': 4.4396, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 10.4481613200154}, {'T_air': -5, 'n_GTU': 0.95219, 'GTU': 157.7391, 'GTU_KPD': 33.8513, 'Turbine': 55.5394, 'KN': 0.0404, 'DK': 6.2846, 'PEN': 0.9221, 'Turbine_Qt': 169.8421, 'ASW_Qt': 2.0637, 'ASW_bull': 1, 'Delta_P_Diafragma': 0.0532, 'INKOND': 4.4385, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 10.492562788018917}, {'T_air': -5, 'n_GTU': 0.91606, 'GTU': 151.7548, 'GTU_KPD': 33.4957, 'Turbine': 54.2408, 'KN': 0.0404, 'DK': 6.2719, 'PEN': 1.3041, 'Turbine_Qt': 166.1195, 'ASW_Qt': 0.0, 'ASW_bull': 2, 'Delta_P_Diafragma': 0.0543, 'INKOND': 4.4387, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0}, {'T_air': -5, 'n_GTU': 0.91813, 'GTU': 152.0977, 'GTU_KPD': 33.5194, 'Turbine': 54.3013, 'KN': 0.0403, 'DK': 6.2726, 'PEN': 1.2774, 'Turbine_Qt': 166.3605, 'ASW_Qt': 0.0, 'ASW_bull': 2, 'Delta_P_Diafragma': 0.0546, 'INKOND': 4.4348, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0}]
# Начался расчет kolichestvo= 2
# [{'T_air': -5, 'n_GTU': 0.97488, 'GTU': 161.4991, 'GTU_KPD': 33.9961, 'Turbine': 56.2718, 'KN': 0.0404, 'DK': 6.2926, 'PEN': 0.7402, 'Turbine_Qt': 172.434, 'ASW_Qt': 4.6807, 'ASW_bull': 1, 'Delta_P_Diafragma': 0.0528, 'INKOND': 4.441, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 20.8963226400308}, {'T_air': -5, 'n_GTU': 0.97002, 'GTU': 160.6934, 'GTU_KPD': 33.9713, 'Turbine': 56.1127, 'KN': 0.0404, 'DK': 6.2908, 'PEN': 0.7736, 'Turbine_Qt': 171.9243, 'ASW_Qt': 4.1274, 'ASW_bull': 1, 'Delta_P_Diafragma': 0.0529, 'INKOND': 4.4434, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 20.985125576037834}, {'T_air': -5, 'n_GTU': 0.89134, 'GTU': 147.6596, 'GTU_KPD': 33.1903, 'Turbine': 53.324, 'KN': 0.0404, 'DK': 6.2632, 'PEN': 1.6232, 'Turbine_Qt': 163.8011, 'ASW_Qt': 0.0, 'ASW_bull': 2, 'Delta_P_Diafragma': 0.0546, 'INKOND': 4.4395, 'ASWatm': False, 'Calculate_minimum': True, 'G_ASW': 0}, {'T_air': -5, 'n_GTU': 0.89631, 'GTU': 148.4827, 'GTU_KPD': 33.2547, 'Turbine': 53.4657, 'KN': 0.0404, 'DK': 6.2649, 'PEN': 1.5542, 'Turbine_Qt': 164.325, 'ASW_Qt': 0.0, 'ASW_bull': 2, 'Delta_P_Diafragma': 0.0551, 'INKOND': 4.4447, 'ASWatm': True, 'Calculate_minimum': True, 'G_ASW': 0}]
# Начался расчет kolichestvo= 3
