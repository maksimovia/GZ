# %%
# Импорт библиотек
import os
import time
import cotel
import Turboustanovka
import GTU
import mat_properties as prop
import numpy as n
import pandas as pd
from scipy.optimize import root

# таблица номинального режима
gas_streams0 = pd.read_excel("streams0.xlsx", sheet_name="gas", index_col=0)
water_streams0 = pd.read_excel(
    "streams0.xlsx", sheet_name="water", index_col=0)
GTU_ISO = pd.read_excel("input.xlsx", sheet_name="ISO", index_col=0)
GTU_input = pd.read_excel("input.xlsx", sheet_name="GTU_input", index_col=0)
# рабочая таблица (=номинал в 1 итерации)
gas_streams = pd.read_excel("streams.xlsx", sheet_name="gas", index_col=0)
water_streams = pd.read_excel("streams.xlsx", sheet_name="water", index_col=0)
# рабочая таблица показателей блоков
heaters = pd.read_excel("blocks.xlsx", sheet_name="heaters", index_col=0)
electric = pd.read_excel("blocks.xlsx", sheet_name="electric", index_col=0)

# Состав газов в номинале
gasmix = "Nitrogen*Oxygen*CO2*Water*Argon"
# Считывание рефпропа
RP = prop.init_REFPROP(r"C:\Program Files (x86)\REFPROP")
fractiongas0 = (
    gas_streams0.at["GTU-PEVD", "N2"],
    gas_streams0.at["GTU-PEVD", "O2"],
    gas_streams0.at["GTU-PEVD", "CO2"],
    gas_streams0.at["GTU-PEVD", "H2O"],
    gas_streams0.at["GTU-PEVD", "Ar"],
)

gas0 = prop.Materials_prop(
    gasmix,
    fractiongas0,
    prop.REFPROP_h_s,
    prop.REFPROP_p_t,
    prop.REFPROP_p_h,
    prop.REFPROP_p_s,
    prop.REFPROP_p_q,
    prop.REFPROP_t_q,
    prop.REFPROP_p_rho,
    RP=RP,
)
water = prop.Materials_prop(
    "water",
    [1.0, 0, 0, 0, 0],
    prop.REFPROP_h_s,
    prop.REFPROP_p_t,
    prop.REFPROP_p_h,
    prop.REFPROP_p_s,
    prop.REFPROP_p_q,
    prop.REFPROP_t_q,
    prop.REFPROP_p_rho,
    RP=RP,
)


# Задание энтальпий газа в номинальном режиме
Temperatures = gas_streams0.loc["GTU-KU":"GPK-out", "T"]
Pressure = gas_streams0.loc["GTU-KU", "P"]
Enthalpies = list(map(lambda x: gas0.p_t(Pressure, x)["h"], Temperatures))
gas_streams0.loc["GTU-KU":"GPK-out", "H"] = Enthalpies


####################################################################################################
# Расчет ГТУ
Gas_turbine = GTU.gtu(GTU_ISO, GTU_input, "GTU-KU")
Gas_turbine_res = Gas_turbine.calc()
electric.at["GTU", "N"] = Gas_turbine_res["N"]
electric.at["GTU", "KPD"] = Gas_turbine_res["eff"]
electric.at["DK", "N"] = Gas_turbine_res["Ndk"]
gas_streams = pd.read_excel("streams.xlsx", sheet_name="gas", index_col=0)
gas_streams.at["GTU-KU", "T"] = Gas_turbine_res["T"]
gas_streams.at["GTU-KU", "G"] = Gas_turbine_res["G"]
gas_streams.at["GTU-KU", "P"] = 0.1
gas_streams.at['GTU-KU', 'H'] = gas0.p_t(
    gas_streams.at['GTU-KU', 'P'], gas_streams.at['GTU-KU', 'T'])['h']
Gas_turbine_composition = pd.read_excel(
    "input.xlsx", sheet_name="Gas_composition0", index_col=0)

# Параметры газа на выходе в КУ
gas_streams.loc["GTU-PEVD", "T":"P"] = gas_streams.loc["GTU-KU", "T":"P"]
gas_streams.at["GTU-PEVD", "G"] = gas_streams.loc["GTU-KU", "G"]
gas_streams.at["GTU-PEVD",
               "N2":"Ar"] = Gas_turbine_composition.loc["Fraction", "N2":"Ar"]

# Состав газов при частичной нагрузке
fractiongas = (
    gas_streams.at["GTU-PEVD", "N2"],
    gas_streams.at["GTU-PEVD", "O2"],
    gas_streams.at["GTU-PEVD", "CO2"],
    gas_streams.at["GTU-PEVD", "H2O"],
    gas_streams.at["GTU-PEVD", "Ar"],
)
gas1 = prop.Materials_prop(
    gasmix,
    fractiongas,
    prop.REFPROP_h_s,
    prop.REFPROP_p_t,
    prop.REFPROP_p_h,
    prop.REFPROP_p_s,
    prop.REFPROP_p_q,
    prop.REFPROP_t_q,
    prop.REFPROP_p_rho,
    RP=RP,
)

# Основные константы
Calcmethod = "hybr"
KPDnasos = 0.8074
KPD = 0.99
Calctolerance = 10**-2
Teplo = 1
Maxiterations_cotel = 10
Maxiterations_KU_TU = 20
Maxiterations_turbine = 30

####################################################################################################
# Инициализируем все
TU = Turboustanovka.turboustanovka(
    water, water_streams0, water_streams, heaters, electric, KPD_SP=0.99, KPDnasos=0.8)
Whole_cotel = cotel.cotel_all(KPD, KPDnasos,  gas0, gas1, water, Calcmethod,
                              gas_streams0, water_streams0, gas_streams, water_streams, heaters, electric)


Vvd0 = 1/water.p_h(water_streams0.at["PEVD-DROSVD", 'P'],
                   water_streams0.at["PEVD-DROSVD", 'H'])['rho']
Vnd0 = 1/water.p_h(water_streams0.at["PPND-DROSND", 'P'],
                   water_streams0.at["PPND-DROSND", 'H'])['rho']
Gvd0 = water_streams0.at["PEVD-DROSVD", 'G']
Gnd0 = water_streams0.at["PPND-DROSND", 'G']
dPvd0 = water_streams0.at["PEVD-DROSVD", 'P'] - \
    water_streams0.at["DROSVD-TURBVD", 'P']
dPnd0 = water_streams0.at["PPND-DROSND", 'P'] - \
    water_streams0.at["DROSND-TURBND", 'P']

####################################################################################################
# Расчет всего
Pnd_it = []
Pvd_it = []
start_time = time.time()
Max_error_P = 2
Max_error_G = 2
Max_error = 2
Error_nd_P = 2
Error_vd_P = 2
Calctolerance_new = 10**-1
Teplo_overflow = 0

#Первое приближение по давлению
G_gas1 = gas_streams.at["GTU-PEVD", "G"]
G_gas0 = gas_streams0.at["GTU-PEVD", "G"]
g_gas = G_gas1/G_gas0
Pvd_1 = 0.4538+7.7601*g_gas
Pnd_1 = -0.0189+0.6885*g_gas
water_streams.at["PPND-DROSND", 'P'] = Pnd_1
water_streams.at["PEVD-DROSVD", 'P'] = Pvd_1
print('Pnd_1', Pnd_1)
print('Pvd_1', Pvd_1)

for i in range(Maxiterations_KU_TU):

    for j in range(Maxiterations_cotel):

        # Расчет котла
        Whole_cotel.calc(Calctolerance_new, Maxiterations_cotel)
        # print('КУ расчитан')

        Gnd1 = water_streams.at["PPND-DROSND", "G"]
        Gnd2 = water_streams.at["DROSND-TURBND", "G"]
        Gvd1 = water_streams.at["PEVD-DROSVD", "G"]
        Gvd2 = water_streams.at["DROSVD-TURBVD", "G"]

        # Перекидываем расходы
        water_streams.at["DROSVD-TURBVD", 'G'] = Gvd1
        water_streams.at["DROSND-TURBND", 'G'] = Gnd1

        # Перекидываем энтальпии
        water_streams.at["DROSVD-TURBVD",
                         'H'] = water_streams.at["PEVD-DROSVD", 'H']
        water_streams.at["DROSND-TURBND",
                         'H'] = water_streams.at["PPND-DROSND", 'H']
        if i > 0 and Teplo == 1:
            teplofikacia = 1
        else:
            teplofikacia = 0
        # Расчет турбины
        TU_res = TU.calculate(
            teplofikacia, calcmethod="hybr", calctolerance=Calctolerance_new, maxiterations=Maxiterations_turbine
        )
        # print('ТУ рассчитана')

        # основные потоки, которые надо сводить по расходу
        # Calctolerance_new=Calctolerance
        # if Max_error > 0.1 and Max_error <= 1:
        #     print('Max_error', 0.01)
        #     Calctolerance_new = Calctolerance*10
        # if Max_error > 1:
        #     print('Max_error', 1)
        Calctolerance_new = Calctolerance*10
        if  i>2:
            print('Переход к оригинально точности расчета',Calctolerance)
            Calctolerance_new = Calctolerance
        # if Max_error_P < Calctolerance:
        #     print('Max_error_10', 0.01)
        #     Calctolerance_new = Calctolerance
        # if Max_error < 0.01:
        #     print('Max_error', 'else')
        #     Calctolerance_new = Calctolerance

        Error_water_G = abs((water_streams.at["SMESHOD-REC", "G"] -
                             water_streams.at["GPK-IND", "G"])/water_streams.at["GPK-IND", "G"]*100)
        Error_nd_G = abs((Gnd1 - Gnd2)/Gnd1*100)
        Error_vd_G = abs((Gvd1 - Gvd2)/Gvd1*100)
        Max_error_G = max(Error_water_G, Error_nd_G, Error_vd_G)
        Max_error = max(Error_water_G, Error_nd_G,
                        Error_vd_G, Error_nd_P, Error_vd_P)
        print('Max_error_G', Max_error_G)
        print('Error_nd_G', Error_nd_G)
        print('Error_vd_G', Error_vd_G)
        print('Error_water_G', Error_water_G)
        if Error_water_G > 20:
            Teplo_overflow = 1
        if abs(Max_error_G) < Calctolerance_new:
            print(
                "Максимальная погрешность определения расхода в КУ+ПТУ", Max_error_G)
            break
        if j == Maxiterations_cotel - 1:
            print("Достигнуто максимальное количество итераций расхода КУ+ПТУ")

    # Переписываю давления
    P_turb_vd = water_streams.at["DROSVD-TURBVD", 'P']
    P_turb_nd = water_streams.at["DROSND-TURBND", 'P']
    Vvd1 = 1/water.p_h(water_streams0.at["PEVD-DROSVD", 'P'],
                       water_streams0.at["PEVD-DROSVD", 'H'])['rho']
    Vnd1 = 1/water.p_h(water_streams0.at["PPND-DROSND", 'P'],
                       water_streams0.at["PPND-DROSND", 'H'])['rho']
    dPvd = dPvd0 * (Gvd1*Vvd1/Gvd0/Vvd0)**2*Vvd0/Vvd1
    dPnd = dPnd0*(Gnd1*Vnd1/Gnd0/Vnd0)**2*Vnd0/Vnd1
    P_kotel_vd = water_streams.at["PEVD-DROSVD", 'P']
    P_kotel_nd = water_streams.at["PPND-DROSND", 'P']
    P_kotel_nd_new = P_turb_nd+dPnd
    P_kotel_vd_new = P_turb_vd+dPvd
    water_streams.at["PPND-DROSND", 'P'] = (P_kotel_nd_new+P_kotel_nd)/2
    water_streams.at["PEVD-DROSVD", 'P'] = (P_kotel_vd_new+P_kotel_vd)/2

    # Закидываю давления в массив
    Pnd_it.append(round(water_streams.loc['PPND-DROSND', 'P'], 5))
    Pvd_it.append(round(water_streams.loc['PEVD-DROSVD', 'P'], 5))
    print('Pnd_it', Pnd_it)
    print('Pvd_it', Pvd_it)

    # Ошибки расчета
    Error_nd_P = abs((P_kotel_nd - P_kotel_nd_new)/P_kotel_nd*100)
    Error_vd_P = abs((P_kotel_vd - P_kotel_vd_new)/P_kotel_vd*100)
    Max_error = max(Error_water_G, Error_nd_G,
                    Error_vd_G, Error_nd_P, Error_vd_P)
    print('Error_nd_P', Error_nd_P)
    print('Error_vd_P', Error_vd_P)
    Max_error_P = max(Error_nd_P, Error_vd_P)
    print('Max_error', Max_error)
    print(
        f"Время {i+1} итерации расчета КУ+ТУ:--- %s сек. --- {round((time.time() - start_time), 1)}")
    if Teplo_overflow == 1:
        print('Слишком большая теплофикационная мощность, расчет окончен.')
        print('Для правильного расчета необходимо повысить мощность ГТУ или уменьшить мощность теплофикации.')
    if abs(Max_error) < Calctolerance and Calctolerance_new == Calctolerance:
        print(
            "Максимальная погрешность определения расходов", Error_water_G)
        break
    if i == Maxiterations_KU_TU - 1:
        print("Достигнуто максимальное количество итераций давления КУ+ПТУ", i+1)

print("Степень сухости пара в ЭВД: ", water.p_h(
    water_streams.at["EVD-IVD", "P"], water_streams.at["EVD-IVD", "H"])["Q"],)
print("Степень сухости пара в ГПК: ", water.p_h(
    water_streams.at["GPK-IND", "P"], water_streams.at["GPK-IND", "H"])["Q"],)

print(f"fin КУ и ТУ:--- {round((time.time() - start_time), 1)} сек. ---")
# Out:
# Pnd_1 0.4830569624668859
# Pvd_1 6.111368953433961
# Fin котел-утилизатора:--- 22.8 сек. ---
# dQ/Qsumm 0.00883701439930131
# Fin турбоустановка:--- 0.05 сек. ---
# Max_error_G 45.43657107528897
# Error_nd_G 17.110655319221095
# Error_vd_G 45.43657107528897
# Error_water_G 0.0
# Fin котел-утилизатора:--- 11.88 сек. ---
# dQ/Qsumm -0.050201364744683036
# Fin турбоустановка:--- 0.07 сек. ---
# Max_error_G 10.51908362887934
# Error_nd_G 10.51908362887934
# Error_vd_G 0.0650550060787859
# Error_water_G 0.0
# Fin котел-утилизатора:--- 4.89 сек. ---
# dQ/Qsumm -0.0005897014356509021
# Fin турбоустановка:--- 0.04 сек. ---
# Max_error_G 0.03558225001268586
# Error_nd_G 0.03558225001268586
# Error_vd_G 0.02531104224087418
# Error_water_G 0.0
# Максимальная погрешность определения расхода в КУ+ПТУ 0.03558225001268586
# Pnd_it [0.47601]
# Pvd_it [5.87196]
# Error_nd_P 2.917786605306355
# Error_vd_P 7.834903205851129
# Max_error 7.834903205851129
# Время 1 итерации расчета КУ+ТУ:--- %s сек. --- 39.7
# Fin котел-утилизатора:--- 11.81 сек. ---
# dQ/Qsumm -0.025232473388526258
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 2.01 сек. ---
# Max_error_G 2.460686926165545
# Error_nd_G 2.460686926165545
# Error_vd_G 0.36404931124013773
# Error_water_G 0.009733498615228526
# Fin котел-утилизатора:--- 9.7 сек. ---
# dQ/Qsumm 0.021505920069060075
# Достигнуто максимальное количество итераций давления верхнего отбора
# Недостаточное количество итераций
# Fin турбоустановка:--- 5.33 сек. ---
# Max_error_G 9.855532225887973
# Error_nd_G 9.855532225887973
# Error_vd_G 0.0709133313092862
# Error_water_G 0.034573701956705866
# Fin котел-утилизатора:--- 4.88 сек. ---
# dQ/Qsumm 0.0030788022347041947
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 1.31 сек. ---
# Max_error_G 0.20354542640669265
# Error_nd_G 0.20354542640669265
# Error_vd_G 0.020510548789541574
# Error_water_G 0.005582108315162365
# Fin котел-утилизатора:--- 2.61 сек. ---
# dQ/Qsumm 0.002115922111401332
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.41 сек. ---
# Max_error_G 0.0029031909045698443
# Error_nd_G 0.002223021122384045
# Error_vd_G 0.0029031909045698443
# Error_water_G 0.0018621503642773085
# Максимальная погрешность определения расхода в КУ+ПТУ 0.0029031909045698443
# Pnd_it [0.47601, 0.46313]
# Pvd_it [5.87196, 5.76259]
# Error_nd_P 5.412485909540638
# Error_vd_P 3.7252793250486036
# Max_error 5.412485909540638
# Время 2 итерации расчета КУ+ТУ:--- %s сек. --- 77.8
# Fin котел-утилизатора:--- 11.52 сек. ---
# dQ/Qsumm -0.0011650834145422529
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.38 сек. ---
# Max_error_G 0.5788697474753518
# Error_nd_G 0.5788697474753518
# Error_vd_G 0.1474620657407942
# Error_water_G 0.0007243744343570821
# Fin котел-утилизатора:--- 2.54 сек. ---
# dQ/Qsumm 0.013494062604192752
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.4 сек. ---
# Max_error_G 0.029314212699967188
# Error_nd_G 0.016014555075429957
# Error_vd_G 0.029314212699967188
# Error_water_G 0.0008015236992608465
# Максимальная погрешность определения расхода в КУ+ПТУ 0.029314212699967188
# Pnd_it [0.47601, 0.46313, 0.45608]
# Pvd_it [5.87196, 5.76259, 5.71238]
# Error_nd_P 3.0427632696709916
# Error_vd_P 1.7426403710187857
# Max_error 3.0427632696709916
# Время 3 итерации расчета КУ+ТУ:--- %s сек. --- 92.7
# Fin котел-утилизатора:--- 6.17 сек. ---
# dQ/Qsumm -0.03155001985890501
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.51 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.27546510114196476
# Error_nd_G 0.27546510114196476
# Error_vd_G 0.0319700507718655
# Error_water_G 0.0003776171947353419
# Достигнуто максимальное количество итераций контура высокого давления
# Fin котел-утилизатора:--- 28.88 сек. ---
# dQ/Qsumm 0.005179042618862614
# Достигнуто максимальное количество итераций давления верхнего отбора
# Недостаточное количество итераций
# Fin турбоустановка:--- 5.24 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 2.5290281489924094
# Error_nd_G 2.5290281489924094
# Error_vd_G 0.053559173462144734
# Error_water_G 0.0016408617365069411
# Fin котел-утилизатора:--- 7.09 сек. ---
# dQ/Qsumm -0.008601672624211904
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 2.94 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.018151711683164016
# Error_nd_G 0.007098112679551699
# Error_vd_G 0.018151711683164016
# Error_water_G 0.00047126908436241903
# Fin котел-утилизатора:--- 2.9 сек. ---
# dQ/Qsumm 0.005467184577672793
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 2.49 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.012568109444948765
# Error_nd_G 0.009356476178569415
# Error_vd_G 0.012568109444948765
# Error_water_G 0.000670029906829356
# Fin котел-утилизатора:--- 5.87 сек. ---
# dQ/Qsumm 0.004264793593430458
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.33 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.0027217714181552786
# Error_nd_G 0.0027217714181552786
# Error_vd_G 0.00023052593294346912
# Error_water_G 0.0004686257792858078
# Максимальная погрешность определения расхода в КУ+ПТУ 0.0027217714181552786
# Pnd_it [0.47601, 0.46313, 0.45608, 0.45052]
# Pvd_it [5.87196, 5.76259, 5.71238, 5.70713]
# Error_nd_P 2.439265771842021
# Error_vd_P 0.18349107654547012
# Max_error 2.439265771842021
# Время 4 итерации расчета КУ+ТУ:--- %s сек. --- 155.1
# Fin котел-утилизатора:--- 14.01 сек. ---
# dQ/Qsumm -1.1127227424537263e-05
# Достигнуто максимальное количество итераций давления верхнего отбора
# Недостаточное количество итераций
# Fin турбоустановка:--- 5.19 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.24972391486226897
# Error_nd_G 0.24972391486226897
# Error_vd_G 0.003794333871660469
# Error_water_G 0.0008565115671822757
# Fin котел-утилизатора:--- 15.5 сек. ---
# dQ/Qsumm -0.007904550424961587
# Достигнуто максимальное количество итераций давления верхнего отбора
# Недостаточное количество итераций
# Fin турбоустановка:--- 2.93 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.0050074987831047755
# Error_nd_G 0.0019935484489278375
# Error_vd_G 0.0050074987831047755
# Error_water_G 0.0013093226285973098
# Максимальная погрешность определения расхода в КУ+ПТУ 0.0050074987831047755
# Pnd_it [0.47601, 0.46313, 0.45608, 0.45052, 0.44807]
# Pvd_it [5.87196, 5.76259, 5.71238, 5.70713, 5.70485]
# Error_nd_P 1.0865446929142173
# Error_vd_P 0.08016115917817351
# Max_error 1.0865446929142173
# Время 5 итерации расчета КУ+ТУ:--- %s сек. --- 192.7
# Fin котел-утилизатора:--- 14.8 сек. ---
# dQ/Qsumm 0.007251381848283406
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 1.85 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.10522214928198145
# Error_nd_G 0.10522214928198145
# Error_vd_G 0.013708456863113576
# Error_water_G 0.0002518123486317889
# Fin котел-утилизатора:--- 5.84 сек. ---
# dQ/Qsumm -0.004696435280307452
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.44 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.034718850853259695
# Error_nd_G 0.034718850853259695
# Error_vd_G 0.001137157312204111
# Error_water_G 7.223079487616323e-05
# Fin котел-утилизатора:--- 2.91 сек. ---
# dQ/Qsumm 0.003656322668767811
# Достигнуто максимальное количество итераций давления верхнего отбора
# Недостаточное количество итераций
# Fin турбоустановка:--- 2.98 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.009197271078137005
# Error_nd_G 0.008117291656097248
# Error_vd_G 0.009197271078137005
# Error_water_G 0.0009891882680953808
# Максимальная погрешность определения расхода в КУ+ПТУ 0.009197271078137005
# Pnd_it [0.47601, 0.46313, 0.45608, 0.45052, 0.44807, 0.44702]
# Pvd_it [5.87196, 5.76259, 5.71238, 5.70713, 5.70485, 5.70308]
# Error_nd_P 0.4709709662668493
# Error_vd_P 0.061790339675188766
# Max_error 0.4709709662668493
# Время 6 итерации расчета КУ+ТУ:--- %s сек. --- 221.5
# Fin котел-утилизатора:--- 14.37 сек. ---
# dQ/Qsumm -0.0038086195477008053
# Достигнуто максимальное количество итераций давления верхнего отбора
# Недостаточное количество итераций
# Fin турбоустановка:--- 3.07 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.0297331705385089
# Error_nd_G 0.0297331705385089
# Error_vd_G 0.011372806042596046
# Error_water_G 0.0006673026144946322
# Fin котел-утилизатора:--- 3.04 сек. ---
# dQ/Qsumm 0.006123707398296778
# Достигнуто максимальное количество итераций давления верхнего отбора
# Недостаточное количество итераций
# Fin турбоустановка:--- 3.04 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.012156744935566335
# Error_nd_G 0.0003643375258582593
# Error_vd_G 0.012156744935566335
# Error_water_G 0.0020652010633794324
# Fin котел-утилизатора:--- 2.95 сек. ---
# dQ/Qsumm -0.0029655697112585563
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.5 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.008357096730616732
# Error_nd_G 0.008357096730616732
# Error_vd_G 0.007778562538993951
# Error_water_G 0.00018555266705424955
# Максимальная погрешность определения расхода в КУ+ПТУ 0.008357096730616732
# Pnd_it [0.47601, 0.46313, 0.45608, 0.45052, 0.44807, 0.44702, 0.44655]
# Pvd_it [5.87196, 5.76259, 5.71238, 5.70713, 5.70485, 5.70308, 5.70245]
# Error_nd_P 0.2105562124685588
# Error_vd_P 0.022358736161830248
# Max_error 0.2105562124685588
# Время 7 итерации расчета КУ+ТУ:--- %s сек. --- 248.5
# Fin котел-утилизатора:--- 6.92 сек. ---
# dQ/Qsumm -0.009501183036652884
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.49 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.01486064386060774
# Error_nd_G 0.010802937211902418
# Error_vd_G 0.01486064386060774
# Error_water_G 0.0002156215683356626
# Fin котел-утилизатора:--- 2.94 сек. ---
# dQ/Qsumm 0.00601642804614543
# Достигнуто максимальное количество итераций давления верхнего отбора
# Недостаточное количество итераций
# Fin турбоустановка:--- 3.08 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.028332516844566613
# Error_nd_G 0.028332516844566613
# Error_vd_G 0.010741559021698878
# Error_water_G 0.0032712574668343737
# Fin котел-утилизатора:--- 2.86 сек. ---
# dQ/Qsumm -0.0014933760912207127
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 2.35 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.010014534486745956
# Error_nd_G 0.010014534486745956
# Error_vd_G 0.0043521442528420716
# Error_water_G 0.0006406570985579592
# Fin котел-утилизатора:--- 2.97 сек. ---
# dQ/Qsumm 0.0012668147575442712
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.71 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.002125115757032533
# Error_nd_G 0.0010474335187687072
# Error_vd_G 0.002125115757032533
# Error_water_G 0.00014508768376245344
# Максимальная погрешность определения расхода в КУ+ПТУ 0.002125115757032533
# Pnd_it [0.47601, 0.46313, 0.45608, 0.45052, 0.44807, 0.44702, 0.44655, 0.44628]
# Pvd_it [5.87196, 5.76259, 5.71238, 5.70713, 5.70485, 5.70308, 5.70245, 5.70231]
# Error_nd_P 0.12068337786157327
# Error_vd_P 0.004925300672020294
# Max_error 0.12068337786157327
# Время 8 итерации расчета КУ+ТУ:--- %s сек. --- 270.8
# Fin котел-утилизатора:--- 6.4 сек. ---
# dQ/Qsumm 0.006051930092887109
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.36 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.06615229023263909
# Error_nd_G 0.06615229023263909
# Error_vd_G 0.016494790972093963
# Error_water_G 0.00011380403818067794
# Fin котел-утилизатора:--- 2.95 сек. ---
# dQ/Qsumm 0.001454799775515309
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.42 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.039293411773100854
# Error_nd_G 0.039293411773100854
# Error_vd_G 0.011947598520042811
# Error_water_G 0.00027446652495307153
# Fin котел-утилизатора:--- 2.88 сек. ---
# dQ/Qsumm -0.004970599712624336
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.51 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.009394648569953642
# Error_nd_G 0.008222478058807057
# Error_vd_G 0.009394648569953642
# Error_water_G 3.965949146087191e-05
# Максимальная погрешность определения расхода в КУ+ПТУ 0.009394648569953642
# Pnd_it [0.47601, 0.46313, 0.45608, 0.45052, 0.44807, 0.44702, 0.44655, 0.44628, 0.44617]
# Pvd_it [5.87196, 5.76259, 5.71238, 5.70713, 5.70485, 5.70308, 5.70245, 5.70231, 5.70239]
# Error_nd_P 0.04666020887924653
# Error_vd_P 0.002944882254384571
# Max_error 0.04666020887924653
# Время 9 итерации расчета КУ+ТУ:--- %s сек. --- 284.3
# Fin котел-утилизатора:--- 3.57 сек. ---
# dQ/Qsumm -0.00680276897746096
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.52 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.05222619008601012
# Error_nd_G 0.05222619008601012
# Error_vd_G 0.007388359253749693
# Error_water_G 0.0001817787709251347
# Достигнуто максимальное количество итераций контура высокого давления
# Fin котел-утилизатора:--- 16.72 сек. ---
# dQ/Qsumm -0.009527951668865694
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.36 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.05080000417841448
# Error_nd_G 0.05080000417841448
# Error_vd_G 0.012934379957823636
# Error_water_G 9.082236336783863e-05
# Fin котел-утилизатора:--- 2.96 сек. ---
# dQ/Qsumm 0.001499902409815335
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.43 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.030060763011483648
# Error_nd_G 0.030060763011483648
# Error_vd_G 0.016697789605900727
# Error_water_G 2.7568190403187856e-05
# Fin котел-утилизатора:--- 2.95 сек. ---
# dQ/Qsumm 0.004257059764729317
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.35 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.013351288843449584
# Error_nd_G 0.013351288843449584
# Error_vd_G 0.007112396897183825
# Error_water_G 0.003673884882086173
# Fin котел-утилизатора:--- 3.01 сек. ---
# dQ/Qsumm -0.002817905700834531
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.54 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.005843187250549595
# Error_nd_G 0.004817266862400939
# Error_vd_G 0.005843187250549595
# Error_water_G 7.642857535340564e-06
# Максимальная погрешность определения расхода в КУ+ПТУ 0.005843187250549595
# Pnd_it [0.47601, 0.46313, 0.45608, 0.45052, 0.44807, 0.44702, 0.44655, 0.44628, 0.44617, 0.44617]
# Pvd_it [5.87196, 5.76259, 5.71238, 5.70713, 5.70485, 5.70308, 5.70245, 5.70231, 5.70239, 5.70207]
# Error_nd_P 0.0005363952801954291
# Error_vd_P 0.011133937468566715
# Max_error 0.011133937468566715
# Время 10 итерации расчета КУ+ТУ:--- %s сек. --- 315.8
# Fin котел-утилизатора:--- 7.47 сек. ---
# dQ/Qsumm 0.0010273376723701892
# Достигнуто максимальное количество итераций давления верхнего отбора
# Недостаточное количество итераций
# Fin турбоустановка:--- 2.91 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.04345279788830614
# Error_nd_G 0.04345279788830614
# Error_vd_G 0.00539690179937558
# Error_water_G 0.0010025162303946903
# Fin котел-утилизатора:--- 2.91 сек. ---
# dQ/Qsumm -0.002655683175419583
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 2.35 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.005348967696236939
# Error_nd_G 0.005134210680066173
# Error_vd_G 0.005348967696236939
# Error_water_G 0.0008533910972713303
# Максимальная погрешность определения расхода в КУ+ПТУ 0.005348967696236939
# Pnd_it [0.47601, 0.46313, 0.45608, 0.45052, 0.44807, 0.44702, 0.44655, 0.44628, 0.44617, 0.44617, 0.44612]
# Pvd_it [5.87196, 5.76259, 5.71238, 5.70713, 5.70485, 5.70308, 5.70245, 5.70231, 5.70239, 5.70207, 5.70222]
# Error_nd_P 0.02304914600910574
# Error_vd_P 0.005315118438050686
# Max_error 0.02304914600910574
# Время 11 итерации расчета КУ+ТУ:--- %s сек. --- 331.4
# Fin котел-утилизатора:--- 2.9 сек. ---
# dQ/Qsumm -0.006510075569279941
# Достигнуто максимальное количество итераций давления верхнего отбора
# Недостаточное количество итераций
# Fin турбоустановка:--- 3.0 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.045905155477777175
# Error_nd_G 0.045905155477777175
# Error_vd_G 0.004839642697824155
# Error_water_G 0.0018480040944402088
# Fin котел-утилизатора:--- 2.94 сек. ---
# dQ/Qsumm 0.006615635070277324
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 0.57 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.013931636686262221
# Error_nd_G 0.0005667161756996708
# Error_vd_G 0.013931636686262221
# Error_water_G 0.00020048090746320677
# Fin котел-утилизатора:--- 2.99 сек. ---
# dQ/Qsumm -0.0038517937360165776
# Расход в конденсатор меньше допустимого (4,44 кг/с)
# Fin турбоустановка:--- 2.12 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.009371172589640394
# Error_nd_G 0.0042385697116690355
# Error_vd_G 0.009371172589640394
# Error_water_G 0.000597676273201121
# Максимальная погрешность определения расхода в КУ+ПТУ 0.009371172589640394
# Pnd_it [0.47601, 0.46313, 0.45608, 0.45052, 0.44807, 0.44702, 0.44655, 0.44628, 0.44617, 0.44617, 0.44612, 0.44615]
# Pvd_it [5.87196, 5.76259, 5.71238, 5.70713, 5.70485, 5.70308, 5.70245, 5.70231, 5.70239, 5.70207, 5.70222, 5.70203]
# Error_nd_P 0.013011884769366074
# Error_vd_P 0.0066534131602535435
# Max_error 0.013011884769366074
# Время 12 итерации расчета КУ+ТУ:--- %s сек. --- 346.0
# Fin котел-утилизатора:--- 3.0 сек. ---
# dQ/Qsumm 0.0025904281956431723
# Достигнуто максимальное количество итераций давления верхнего отбора
# Недостаточное количество итераций
# Fin турбоустановка:--- 2.95 сек. ---
# Переход к оригинально точности расчета 0.01
# Max_error_G 0.009083144843338772
# Error_nd_G 0.009083144843338772
# Error_vd_G 0.00438478398610122
# Error_water_G 0.0014689029341812489
# Максимальная погрешность определения расхода в КУ+ПТУ 0.009083144843338772
# Pnd_it [0.47601, 0.46313, 0.45608, 0.45052, 0.44807, 0.44702, 0.44655, 0.44628, 0.44617, 0.44617, 0.44612, 0.44615, 0.44615]
# Pvd_it [5.87196, 5.76259, 5.71238, 5.70713, 5.70485, 5.70308, 5.70245, 5.70231, 5.70239, 5.70207, 5.70222, 5.70203, 5.7018]
# Error_nd_P 0.0012453106580813528
# Error_vd_P 0.008194314511580841
# Max_error 0.009083144843338772
# Время 13 итерации расчета КУ+ТУ:--- %s сек. --- 351.9
# Максимальная погрешность определения расходов 0.0014689029341812489
# Степень сухости пара в ЭВД:  0.018258595292033688
# Степень сухости пара в ГПК:  -9999990.0
# fin КУ и ТУ:--- 351.9 сек. ---

# %%
import matplotlib.pyplot as plt
import matplotlib

# plt.style.use('_mpl-gallery')
# plt.figure(figsize=(20,5))
# plot
fig, ax = plt.subplots()
x = range(0, i+1)
y = Pvd_it
plt.plot(x, y, linewidth=2.0)
fig.set_size_inches(20, 5)

# ax.set(xlim=(0, 8),
#        ylim=(0, 8))
# loc = matplotlib.ticker.LinearLocator(numticks = len(x)-1)
# plt.gca().xaxis.set_major_locator(loc)
ax.set_xticks(x)
plt.show()

# %%
# Вывод газовых потоков
gas_streams

# %%
# Вывод водяных потоков
water_streams

# %%
Errors_water = abs(water_streams - water_streams0)/water_streams0*100
Errors_gas = abs(gas_streams-gas_streams0)/gas_streams0*100
Errors_gas
Errors_water

# %%
gas_streams0

# %%
water_streams0

# %%
electric

# %%
heaters

# %%
GTU_input

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))
Qg = [0,
      heaters.loc['PEVD', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg'] +
      heaters.loc['EVD', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg'] +
      heaters.loc['EVD', 'Qg']+heaters.loc['PPND', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg']+heaters.loc['EVD',
                                                                     'Qg']+heaters.loc['PPND', 'Qg']+heaters.loc['IND', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg']+heaters.loc['EVD', 'Qg'] +
      heaters.loc['PPND', 'Qg'] +
      heaters.loc['IND', 'Qg']+heaters.loc['GPK', 'Qg']
      ]
Qw = [0,
      heaters.loc['PEVD', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg'] +
      heaters.loc['EVD', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg'] +
      heaters.loc['EVD', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg'] +
      heaters.loc['EVD', 'Qg']+heaters.loc['PPND', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg']+heaters.loc['EVD',
                                                                     'Qg']+heaters.loc['PPND', 'Qg']+heaters.loc['IND', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg']+heaters.loc['EVD',
                                                                     'Qg']+heaters.loc['PPND', 'Qg']+heaters.loc['IND', 'Qg'],
      heaters.loc['PEVD', 'Qg']+heaters.loc['IVD', 'Qg']+heaters.loc['EVD', 'Qg'] +
      heaters.loc['PPND', 'Qg'] +
      heaters.loc['IND', 'Qg']+heaters.loc['GPK', 'Qg']
      ]
Tg = gas_streams.loc['GTU-PEVD':'GPK-out', 'T']
Tw = [water_streams.loc['PEVD-DROSVD', 'T'],
      water_streams.loc['IVD-PEVD', 'T'],
      water_streams.loc['IVD-PEVD', 'T'],
      water_streams.loc['EVD-IVD', 'T'],
      water_streams.loc['PEN-EVD', 'T'],
      water_streams.loc['PPND-DROSND', 'T'],
      water_streams.loc['IND-PPND', 'T'],
      water_streams.loc['IND-PPND', 'T'],
      water_streams.loc['GPK-REC', 'T'],
      water_streams.loc['REC-GPK', 'T'],
      ]
plt.plot(Qg, Tg, color='red')
plt.plot(Qw[0:2], Tw[0:2], color='blue')
plt.plot(Qw[1:3], Tw[1:3], color='blue')
plt.plot(Qw[3:5], Tw[3:5], color='blue')
plt.plot(Qw[5:7], Tw[5:7], color='blue')
plt.plot(Qw[6:8], Tw[6:8], color='blue')
plt.plot(Qw[8:10], Tw[8:10], color='blue')
plt.xlabel('Q')
plt.ylabel('T')
plt.legend(['gas', 'water'])
plt.show()
